# %% [markdown]
# # Code Progress for Identifying Presence or Absence of Seismic Facies in Seismic Images Using Deep Learning

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Nov  2 22:00:05 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import files

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import math
from scipy.signal.windows import triang
from scipy.signal import convolve2d as conv2

from tqdm.notebook import tqdm #progress bar

import cv2

import datetime

import tensorflow as tf
from tensorflow.keras.layers import *
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau

from sklearn.model_selection import train_test_split

from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#drive = GoogleDrive()

# %%
data_train_parihaka = np.load('/content/drive/MyDrive/Dataset /data_train.npz',  
               allow_pickle=True, mmap_mode = 'r')['data']


label_train_parihaka = np.load('/content/drive/MyDrive/Dataset /labels_train.npz',  
               allow_pickle=True, mmap_mode = 'r')['labels']

# %% [markdown]
# ### Data Preprocessing
# #### Loading in Dataset 1 (Parihaka)

# %%
print('Shape X:', data_train_parihaka.shape)
print('Shape Y:', label_train_parihaka.shape)
# Out:
# Shape X: (1006, 782, 590)
# Shape Y: (1006, 782, 590)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(data_train_parihaka[:,:,200], cmap='seismic')
ax[1].imshow(label_train_parihaka[:,:,200], cmap='seismic')

# %% [markdown]
# #### Loading Dataset 2 (Netherlands F3 Block)
# ##### We will use this one for transfer learning once we have trustworthy weights.

# %%
data_train_netherlands = np.load('/content/drive/MyDrive/Dataset /Dataset_2/train_seismic.npy')


label_train_netherlands = np.load('/content/drive/MyDrive/Dataset /Dataset_2/train_labels.npy')

# %%
print('Shape X:', data_train_netherlands.shape)
print('Shape Y:', label_train_netherlands.shape)
# Out:
# Shape X: (401, 701, 255)
# Shape Y: (401, 701, 255)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(data_train_netherlands[400,:,:].T, cmap='seismic')
ax[1].imshow(label_train_netherlands[400,:,:].T, cmap='seismic')

# %%
data_test1_netherlands = np.load('/content/drive/MyDrive/Dataset /Dataset_2/test1_seismic.npy')


label_test1_netherlands= np.load('/content/drive/MyDrive/Dataset /Dataset_2/test1_labels.npy')

# %%
print('Shape X:', data_test1_netherlands.shape)
print('Shape Y:', label_test1_netherlands.shape)
# Out:
# Shape X: (200, 701, 255)
# Shape Y: (200, 701, 255)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(data_test1_netherlands[20,:,:].T, cmap='seismic')
ax[1].imshow(label_test1_netherlands[20,:,:].T, cmap='seismic')

# %% [markdown]
# ## Implement Data Preprocessing
#
# ### Gain + RMS

# %%
def gain(data,dt,parameters):
    nt,nx = data.shape
    dout = np.zeros(data.shape)
    L = parameters/dt+1
    L = np.floor(L/2)
    h = triang(2*L+1)
    shaped_h  = h.reshape(len(h),1)
    for k in range(nx):
        aux = data[:,k]
        e = aux**2
        shaped_e = e.reshape(len(e),1)
        rms = np.sqrt(conv2(shaped_e,shaped_h,"same"))
        epsi = 1e-10*max(rms)
        op = rms/(rms**2+epsi)
        op = op.reshape(len(op),)
        dout[:,k] = data[:,k]*op
    for k in range(nx):
        aux = dout[:,k]
        amax = np.sqrt(sum(aux**2)/nt)
        dout[:,k] = dout[:,k]/amax
    return dout

# %%
test_image=data_train_parihaka[:,200,:]
test_gain =gain(test_image,3e-3,0.8)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(data_train_parihaka[:,200,:], cmap='seismic')
ax[1].imshow(test_gain, cmap='seismic')

# %%
# load in an RMS processed dataset
data_train_parihaka_pp = np.load('/content/drive/MyDrive/Dataset /data_train_processed.npz',  
               allow_pickle=True, mmap_mode = 'r')['data']

# %% [markdown]
# 2-D Image Making

# %%
training_img_data = []
training_label_data = []

for i in tqdm(range(0, 580)): #reshaping the images into appropriate sizes 
  img = data_train_parihaka_pp[:, :, i] 
  label = label_train_parihaka[:, :, i]

  img = np.expand_dims(img, axis=2).astype('float32')
  label = np.expand_dims(label, axis=2).astype('float32')

  img = cv2.resize(img, (128, 128))
  label = cv2.resize(label, (128, 128))

  img = img/np.amax(img)
  img = np.clip(img, 0, 255)
  img = (img*255).astype(int)

  img = img/255.

  img = cv2.merge([img,img,img])

  training_img_data.append(img) 
  training_label_data.append(label)
# Out:
#   0%|          | 0/580 [00:00<?, ?it/s]

# %%
print('Before Data Reshape', np.array(data_train_parihaka_pp).shape)
print('After Data Reshape', np.array(training_img_data).shape)

print('Before Target Reshape', np.array(label_train_parihaka).shape)
print('After Target Reshape', np.array(training_label_data).shape)
# Out:
# Before Data Reshape (1006, 782, 590)
# After Data Reshape (580, 128, 128, 3)
# Before Target Reshape (1006, 782, 590)
# After Target Reshape (580, 128, 128)

# %%
training_img_data = np.asarray(training_img_data)

training_label_data = np.asarray(training_label_data)

print(training_label_data.shape)
# Out:
# (580, 128, 128)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(training_img_data[0,:,:,:], cmap='seismic')
ax[1].imshow(training_label_data[:,:,10], cmap='seismic')

# %%
# Augmentation
datagen = ImageDataGenerator(horizontal_flip = True, shear_range = 0.2, zoom_range = 0.2)
datagen_test = ImageDataGenerator(horizontal_flip = True)

datagen.fit(training_img_data)

# %% [markdown]
# ## Processing F3 Data

# %%
training_img_data_f3 = []
training_label_data_f3 = []

for i in tqdm(range(0, 401)): #reshaping the images into appropriate sizes 
  img = data_train_netherlands[i, :, :].T
  label = label_train_netherlands[i, :, :].T

  img = np.expand_dims(img, axis=2).astype('float32')
  label = np.expand_dims(label, axis=2).astype('float32')

  img = cv2.resize(img, (128, 128))
  label = cv2.resize(label, (128, 128))

  img = img/np.amax(img)
  img = np.clip(img, 0, 255)
  img = (img*255).astype(int)

  img = img/255.

  img = cv2.merge([img,img,img])

  training_img_data_f3.append(img) 
  training_label_data_f3.append(label)
# Out:
#   0%|          | 0/401 [00:00<?, ?it/s]

# %%
test1_img_data_f3 = []
test1_label_data_f3 = []

for i in tqdm(range(0, 200)): #reshaping the images into appropriate sizes 
  img = data_test1_netherlands[i, :, :].T 
  label = label_test1_netherlands[i, :, :].T

  img = np.expand_dims(img, axis=2).astype('float32')
  label = np.expand_dims(label, axis=2).astype('float32')

  img = cv2.resize(img, (128, 128))
  label = cv2.resize(label, (128, 128))

  img = img/np.amax(img)
  img = np.clip(img, 0, 255)
  img = (img*255).astype(int)

  img = img/255.

  img = cv2.merge([img,img,img])

  test1_img_data_f3.append(img) 
  test1_label_data_f3.append(label)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
training_img_data_f3 = np.asarray(training_img_data_f3)

training_label_data_f3 = np.asarray(training_label_data_f3)

test1_img_data_f3 = np.asarray(test1_img_data_f3)

test1_label_data_f3 = np.asarray(test1_label_data_f3)


print('Converted F3 Dims:', training_img_data_f3.shape)
print('Converted F3 Dims (Test):', test1_img_data_f3.shape)
# Out:
# Converted F3 Dims: (401, 128, 128, 3)
# Converted F3 Dims (Test): (200, 128, 128, 3)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(test1_img_data_f3[20,:,:,:], cmap='seismic')
ax[1].imshow(test1_label_data_f3[100,:,:], cmap='seismic')

# %%
# Augmentation
datagen_f3 = ImageDataGenerator(horizontal_flip = True, shear_range = 0.2, zoom_range = 0.6)

datagen_f3.fit(test1_img_data_f3)

# %% [markdown]
# Developing the Model Using Keras API
#
# Attempt #1: U-Net without Augmentation

# %%
ACTIVATION = 'relu'
ACTIVATION_OUT = 'softmax'
initializer = 'he_normal'
input_size = np.array(training_img_data).shape[1:]
N_classes = 7

# %%
def UNet1(input_size, N_CLASSES, activation_name, initialization_name, DropoutRatio = 0.5): 
  # Encoder

  # Block encoder 1
  inputs = Input(shape=input_size)
  #data_augmentation
  conv_enc_1 = Conv2D(64, 3, activation = ACTIVATION, padding='same', kernel_initializer=initializer)(inputs)
  conv_enc_1 = BatchNormalization()(conv_enc_1)
  conv_enc_1 = Conv2D(64, 3, activation = ACTIVATION, padding='same', kernel_initializer=initializer)(conv_enc_1)
  conv_enc_1 = BatchNormalization()(conv_enc_1)
  conv_enc_1 = Activation(ACTIVATION)(conv_enc_1)

  # Block encoder 2
  max_pool_enc_2 = MaxPooling2D(pool_size=(2, 2))(conv_enc_1)
  max_pool_enc_2 = Dropout(DropoutRatio/2)(max_pool_enc_2)
  conv_enc_2 = Conv2D(128, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(max_pool_enc_2)
  conv_enc_2 = BatchNormalization()(conv_enc_2)
  conv_enc_2 = Conv2D(128, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(conv_enc_2)
  conv_enc_2 = BatchNormalization()(conv_enc_2)
  conv_enc_2 = Activation(ACTIVATION)(conv_enc_2)

  # Block  encoder 3
  max_pool_enc_3 = MaxPooling2D(pool_size=(2, 2))(conv_enc_2)
  max_pool_enc_3 = Dropout(DropoutRatio)(max_pool_enc_3)
  conv_enc_3 = Conv2D(256, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(max_pool_enc_3)
  conv_enc_3 = BatchNormalization()(conv_enc_3)
  conv_enc_3 = Conv2D(256, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(conv_enc_3)
  conv_enc_3 = BatchNormalization()(conv_enc_3)
  conv_enc_3 = Activation(ACTIVATION)(conv_enc_3)

  # Block  encoder 4
  max_pool_enc_4 = MaxPooling2D(pool_size=(2, 2))(conv_enc_3)
  max_pool_enc_4 = Dropout(DropoutRatio)(max_pool_enc_4)
  conv_enc_4 = Conv2D(512, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(max_pool_enc_4)
  conv_enc_4 = BatchNormalization()(conv_enc_4)
  conv_enc_4 = Conv2D(512, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(conv_enc_4)
  conv_enc_4 = BatchNormalization()(conv_enc_4)
  conv_enc_4 = Activation(ACTIVATION)(conv_enc_4)
  #

  # ----------- #
  maxpool = MaxPooling2D(pool_size=(2, 2))(conv_enc_4)
  maxpool = Dropout(DropoutRatio)(maxpool)
  conv = Conv2D(1024, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(maxpool)
  conv = BatchNormalization()(conv)
  conv = Conv2D(1024, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(conv)
  conv = BatchNormalization()(conv)
  conv = Activation(ACTIVATION)(conv)

  # ----------- #

  # Decoder

  # Block decoder 1
  up_dec_1 = Conv2D(512, 2, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(UpSampling2D(size = (2,2))(conv))
  merge_dec_1 = concatenate([conv_enc_4, up_dec_1], axis = 3)
  merge_dec_1 = Dropout(DropoutRatio)(merge_dec_1)
  conv_dec_1 = Conv2D(512, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(merge_dec_1)
  conv_dec_1 = BatchNormalization()(conv_dec_1)
  conv_dec_1 = Conv2D(512, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(conv_dec_1)
  conv_dec_1 = BatchNormalization()(conv_dec_1)
  conv_dec_1 = Activation(ACTIVATION)(conv_dec_1)

  # Block decoder 2
  up_dec_2 = Conv2D(256, 2, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(UpSampling2D(size = (2,2))(conv_dec_1))
  merge_dec_2 = concatenate([conv_enc_3, up_dec_2], axis = 3)
  merge_dec_2 = Dropout(DropoutRatio)(merge_dec_2)
  conv_dec_2 = Conv2D(256, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(merge_dec_2)
  conv_dec_2 = BatchNormalization()(conv_dec_2)
  conv_dec_2 = Conv2D(256, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(conv_dec_2)
  conv_dec_2 = BatchNormalization()(conv_dec_2)
  conv_dec_2 = Activation(ACTIVATION)(conv_dec_2)

  # Block decoder 3
  up_dec_3 = Conv2D(128, 2, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(UpSampling2D(size = (2,2))(conv_dec_2))
  merge_dec_3 = concatenate([conv_enc_2, up_dec_3], axis = 3)
  merge_dec_3 = Dropout(DropoutRatio)(merge_dec_3)
  conv_dec_3 = Conv2D(128, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(merge_dec_3)
  conv_dec_3 = BatchNormalization()(conv_dec_3)
  conv_dec_3 = Conv2D(128, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(conv_dec_3)
  conv_dec_3 = BatchNormalization()(conv_dec_3)
  conv_dec_3 = Activation(ACTIVATION)(conv_dec_3)

  # Block decoder 4
  up_dec_4 = Conv2D(64, 2, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(UpSampling2D(size = (2,2))(conv_dec_3))
  merge_dec_4 = concatenate([conv_enc_1, up_dec_4], axis = 3)
  merge_dec_4 = Dropout(DropoutRatio)(merge_dec_4)
  conv_dec_4 = Conv2D(64, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(merge_dec_4)
  conv_dec_4 = BatchNormalization()(conv_dec_4)
  conv_dec_4 = Conv2D(64, 3, activation = ACTIVATION, padding = 'same', kernel_initializer = initializer)(conv_dec_4)
  conv_dec_4 = BatchNormalization()(conv_dec_4)
  conv_dec_4 = Activation(ACTIVATION)(conv_dec_4)

  #last = tf.keras.layers.Conv2DTranspose(1, 3, strides=1, padding='same')(conv_dec_4) 
  output = Conv2D(N_CLASSES, 1, activation = ACTIVATION_OUT)(conv_dec_4)

  # pred_mask = tf.argmax(output, axis=-1)
  # # pred_mask becomes [IMG_SIZE, IMG_SIZE]
  # # but matplotlib needs [IMG_SIZE, IMG_SIZE, 1]
  # pred_mask = tf.expand_dims(pred_mask, axis=-1)
  # pred_mask = tf.cast(pred_mask, tf.int64)
   # Lets create the model. Here we initialize the Keras model instance. We use this later to train/test. 
  
  model = tf.keras.Model(inputs = inputs, outputs = output)

  return inputs, output

# %% [markdown]
# #### Create the Model

# %%
inputs, output = UNet1(input_size, N_CLASSES = N_classes, activation_name = ACTIVATION, initialization_name= initializer)

pari_model_unet = tf.keras.Model(inputs = inputs, outputs = output)

print(pari_model_unet.summary())

# %% [markdown]
# #### Compile the Model
#
# Add in our optimizers. We will start with ADAM and binary cross-entropy.

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f**2) + K.sum(y_pred_f**2) + 1)

def dice_loss(y_true,y_pred):
    return 1-dice_coef(y_true,y_pred)

def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
model_path="{}.h5".format('fixed_model_unet_1') #hdf5
checkpoint = ModelCheckpoint(model_path, monitor='val_loss', verbose=1,save_best_only=True, mode='min', save_weights_only = False)

# %%
pari_model_unet.compile(optimizer=Adam(learning_rate=0.0001), loss = tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy' , dice_coef])

# %% [markdown]
# Visualize a Sample Prediction

# %%
print(training_img_data.shape)
print(training_label_data.shape)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(training_img_data, training_label_data,test_size=0.2, shuffle= True)

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_images=True, update_freq='batch')

#tf.cast(training_label_data, tf.float32)
#model_history = pari_model_unet.fit(training_img_data, training_label_data, validation_split=0.2, epochs=50, callbacks=[tensorboard_callback])
model_history = pari_model_unet.fit(datagen.flow(x_train, y_train), validation_data=(x_valid, y_valid), epochs=100, callbacks=[tensorboard_callback, checkpoint])

# %%
def PlotHistory(_model, feature, start_epoch = 0, path_file = None):
    val = "val_" + feature
    
    plt.xlabel('Epoch Number - ' + str(start_epoch))
    plt.ylabel(feature)
    plt.plot(_model.history[feature][start_epoch:])
    plt.plot(_model.history[val][start_epoch:])
    plt.title(val)
    plt.legend(["train_"+feature, val])

# %%
PlotHistory(model_history, 'loss')

# %%
PlotHistory(model_history, 'accuracy')

# %%
pred_test = pari_model_unet.predict(training_img_data)
print(pred_test.shape)
pred_mask = tf.argmax(pred_test, axis=-1)
  # # pred_mask becomes [IMG_SIZE, IMG_SIZE]
  # # but matplotlib needs [IMG_SIZE, IMG_SIZE, 1]
pred_mask = tf.expand_dims(pred_mask, axis=-1)
print(pred_mask.shape)
# Out:
# (580, 128, 128, 7)
# (580, 128, 128, 1)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(pred_mask[400, :, :, 0])
ax[1].imshow(training_label_data[400, :, :])

print(pred_test)
# Out:
# [[[[1.15084723e-02 1.21051390e-02 1.16723767e-02 ... 9.19940114e-01
#     1.89454630e-02 1.36038223e-02]
#    [7.53825181e-04 7.37932278e-04 4.11382469e-04 ... 9.94191825e-01
#     2.23974185e-03 7.87498662e-04]
#    [2.16301443e-04 2.05827222e-04 7.90479389e-05 ... 9.98491883e-01
#     6.39243808e-04 1.41818367e-04]
#    ...
#    [4.70527477e-04 4.12964524e-04 2.39005065e-04 ... 9.97348189e-01
#     7.93736952e-04 2.62505957e-04]
#    [7.19882082e-04 1.07795524e-03 6.26620313e-04 ... 9.95152712e-01
#     1.09606620e-03 4.80713847e-04]
#    [9.19613894e-03 1.54854786e-02 6.46004779e-03 ... 9.44290757e-01
#     6.90537365e-03 6.24601915e-03]]
#
#   [[2.10788287e-03 1.67507923e-03 1.18211471e-03 ... 9.87314820e-01
#     3.31741618e-03 1.67330389e-03]
#    [2.05005650e-04 1.52691107e-04 3.95625757e-05 ... 9.98610139e-01
#     4.96462279e-04 1.18410106e-04]
#    [4.55287591e-05 4.21661280e-05 5.27362863e-06 ... 9.99647379e-01
#     1.49397834e-04 2.22855833e-05]
#    ...
#    [9.04497720e-05 5.25342621e-05 1.22733081e-05 ... 9.99559343e-01
#     1.43958358e-04 1.79724557e-05]
#    [1.31985740e-04 1.31439199e-04 5.14545172e-05 ... 9.99337256e-01
#     1.37226569e-04 2.24815394e-05]
#    [6.01721229e-04 1.29265699e-03 5.88986266e-04 ... 9.95388985e-01
#     1.47104685e-04 4.04552384e-06]
#    ...
#    [1.38893694e-04 9.99424100e-01 4.93399384e-05 ... 3.44732180e-05
#     2.59889552e-04 1.88238409e-05]
#    [4.36706498e-04 9.98455882e-01 1.90532912e-04 ... 1.20575816e-04
#     5.35750180e-04 7.01811659e-05]
#    [5.19564515e-03 9.63792145e-01 9.14550852e-03 ... 3.37439124e-03
#     7.22316606e-03 7.90234841e-03]]
#
#   [[1.87743572e-03 9.84194875e-01 4.00919514e-03 ... 2.20893882e-03
#     4.73331474e-03 1.79374719e-03]
#    [6.62958919e-05 9.99293566e-01 5.69398726e-05 ... 7.09531523e-05
#     4.57503804e-04 2.40707323e-05]
#    [2.15038417e-05 9.99810517e-01 1.03618031e-05 ... 8.91040509e-06
#     1.37212643e-04 2.23110055e-06]
#    ...
#    [9.77427917e-05 9.99471247e-01 3.01592736e-05 ... 3.36747944e-05
#     3.23472777e-04 1.21139101e-05]
#    [2.37348664e-04 9.98968005e-01 1.53480156e-04 ... 7.70691258e-05
#     3.96656047e-04 6.00685089e-05]
#    [4.02381178e-03 9.64716554e-01 8.77333339e-03 ... 3.35727539e-03
#     8.31917301e-03 7.72094866e-03]]
#
#   [[1.40430601e-02 8.92187476e-01 2.86758337e-02 ... 1.76304225e-02
#     1.56871043e-02 1.90563966e-02]
#    [7.21240882e-04 9.95444894e-01 6.66239648e-04 ... 7.31498527e-04
#     1.32697611e-03 5.53455146e-04]
#    [1.48655337e-04 9.98942792e-01 1.04255589e-04 ... 1.56808877e-04
#     4.38120042e-04 6.80524900e-05]
#    ...
#    [2.93875026e-04 9.98433173e-01 1.43850193e-04 ... 1.78072791e-04
#     6.74625859e-04 1.05851323e-04]
#    [1.40242954e-03 9.93606448e-01 1.01927086e-03 ... 6.90414861e-04
#     2.06893566e-03 6.19758619e-04]
#    [1.67005975e-02 8.77853036e-01 2.29240619e-02 ... 1.45617221e-02
#     2.47639809e-02 2.96601914e-02]]]]

# %% [markdown]
# Importing the Test Data

# %%
data_test_parihaka_1 = np.load('/content/drive/MyDrive/Dataset /data_test_1.npz')


data_test_parihaka_2 = np.load('/content/drive/MyDrive/Dataset /data_test_2.npz')

data_test_parihaka_1 = data_test_parihaka_1['data']
data_test_parihaka_2 = data_test_parihaka_2['data']

# %%
# Plot our test data examples
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(data_test_parihaka_1[:,:,1])
ax[1].imshow(data_test_parihaka_2[:,:,1])

print(data_test_parihaka_1.shape)
# Out:
# (1006, 782, 251)

# %%
testing_img_data_1 = []
testing_img_data_2 = []

def preprocess_input(data_in, data_out, axis):
  for i in range(0, axis):
    img = data_in[:, :, i]
    img = np.expand_dims(img, axis=2).astype('float32')
    

    img = cv2.resize(img, (128, 128))

    img = img/np.amax(img)
    img = np.clip(img, 0, 255)
    img = (img*255).astype(int)
    img = cv2.merge([img,img,img])

    data_out.append(img)

  return data_out

testing_img_data_1 = preprocess_input(data_test_parihaka_1, testing_img_data_1, 251)
testing_img_data_2 = preprocess_input(data_test_parihaka_2, testing_img_data_2, 251)

# %%
testing_img_data_1 = np.asarray(testing_img_data_1)
testing_img_data_2 = np.asarray(testing_img_data_2)

# %%
testing_img_data_1.shape
# Out:
# (251, 128, 128, 3)

# %%
# Plot our test data examples
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(testing_img_data_1[100,:,:,:])
ax[1].imshow(testing_img_data_2[100,:,:,:])

# %%
pred_test_data_pari = pari_model_unet.predict(testing_img_data_1)

print(pred_test_data_pari.shape)
pred_mask_test_pari = tf.argmax(pred_test_data_pari, axis=-1)
  # # pred_mask becomes [IMG_SIZE, IMG_SIZE]
  # # but matplotlib needs [IMG_SIZE, IMG_SIZE, 1]
pred_mask_test_pari = tf.expand_dims(pred_mask_test_pari, axis=-1)
print(pred_mask_test_pari.shape)
# Out:
# (251, 128, 128, 7)
# (580, 128, 128, 1)

# %%
plt.imshow(pred_mask_test_pari[200, :, :, 0])

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(pred_mask_test_pari[4, :, :, 0])
ax[0].set_xlabel('X (km)')
ax[0].set_ylabel('Time (s)')
ax[0].set_title('Predicted Facies')
fig.suptitle('Prediction with Test (Parihaka)')

# %% [markdown]
# # Transfer Learning with U-Net

# %%
base_model = tf.keras.models.load_model('/content/drive/MyDrive/Dataset /fixed_model_unet_1.h5')

# %%
# for layer in base_model.layers:
#   layer.trainable = False

for layer in base_model.layers[:69]:
   layer.trainable = False
for layer in base_model.layers[69:]:
   layer.trainable = True

# %%
N_CLASSES_F3 = 7
transfer_out = base_model.output
transfer_out = tf.keras.layers.Conv2D(N_CLASSES_F3, 1, activation = 'softmax', name='transfer_notune')(transfer_out)

# %%
transfer_model_unet = tf.keras.Model(inputs=base_model.input, outputs=transfer_out)

# %%
#for layer in base_model.layers:
  #layer.trainable = False

# %%
model_path_transfer = "{}.h5".format('fixed_model_unet_1_transfer') #hdf5
checkpoint = ModelCheckpoint(model_path_transfer, monitor='val_loss', verbose=1,save_best_only=True, mode='min', save_weights_only = False)

# %%
transfer_model_unet.compile(optimizer=Adam(learning_rate=0.001), loss = tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy', dice_coef])

# %%
x_split, x_test_f3, y_split, y_test_f3 = train_test_split(training_img_data_f3, training_label_data_f3,test_size=0.98, shuffle= False)
x_train_f3, x_val_f3, y_train_f3, y_val_f3 = train_test_split(x_split, y_split, test_size=0.2, shuffle= False)

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_images=True, update_freq='batch')

# transfer_model_history = transfer_model_unet.fit(x_train_f3, y_train_f3, validation_data=(x_val_f3, y_val_f3), epochs=20 callbacks=[tensorboard_callback, checkpoint]) 
transfer_model_history = transfer_model_unet.fit(datagen_f3.flow(x_train_f3, y_train_f3), validation_data=(x_val_f3, y_val_f3), epochs=400, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/400
# 1/1 [==============================] - 9s 9s/step - loss: 1.7920 - accuracy: 0.1536 - val_loss: 1.7934 - val_accuracy: 0.1970
# Epoch 2/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.7857 - accuracy: 0.1578 - val_loss: 1.7904 - val_accuracy: 0.2017
# Epoch 3/400
# 1/1 [==============================] - 6s 6s/step - loss: 1
400
# 1/1 [==============================] - 6s 6s/step - loss: 1.7059 - accuracy: 0.5214 - val_loss: 1.7083 - val_accuracy: 0.6390
# Epoch 32/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.7014 - accuracy: 0.6597 - val_loss: 1.7056 - val_accuracy: 0.6404
# Epoch 33/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.7003 - accuracy: 0.6607 - val_loss: 1.7029 - val_accuracy: 0.6419
# Epoch 34/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.6974 - accuracy: 0.6609 - val_loss: 1.7002 - val_accuracy: 0.6434
# Epoch 35/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6943 - accuracy: 0.6638 - val_loss: 1.6975 - val_accuracy: 0.6447
# Epoch 36/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6925 - accuracy: 0.6626 - val_loss: 1.6948 - val_accuracy: 0.6462
# Epoch 37/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6913 - accuracy: 0.6654 - val_loss: 1.6921 - val_accuracy: 0.6474
# Epoch 38/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6884 - accuracy: 0.6650 - val_loss: 1.6894 - val_accuracy: 0.6490
# Epoch 39/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6848 - accuracy: 0.6674 - val_loss: 1.6867 - val_accuracy: 0.6505
# Epoch 40/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6820 - accuracy: 0.6699 - val_loss: 1.6840 - val_accuracy: 0.6522
# Epoch 41/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6789 - accuracy: 0.6720 - val_loss: 1.6813 - val_accuracy: 0.6538
# Epoch 42/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.6775 - accuracy: 0.6717 - val_loss: 1.6786 - val_accuracy: 0.6554
# Epoch 43/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6753 - accuracy: 0.6720 - val_loss: 1.6759 - val_accuracy: 0.6569
# Epoch 44/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6739 - accuracy: 0.6709 - val_loss: 1.6732 - val_accuracy: 0.6585
# Epoch 45/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6714 - accuracy: 0.6722 - val_loss: 1.6705 - val_accuracy: 0.6599
# Epoch 46/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6660 - accuracy: 0.6788 - val_loss: 1.6678 - val_accuracy: 0.6615
# Epoch 47/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6634 - accuracy: 0.6774 - val_loss: 1.6651 - val_accuracy: 0.6630
# Epoch 48/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6611 - accuracy: 0.6795 - val_loss: 1.6625 - val_accuracy: 0.6644
# Epoch 49/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.6611 - accuracy: 0.6745 - val_loss: 1.6598 - val_accuracy: 0.6656
# Epoch 50/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6564 - accuracy: 0.6806 - val_loss: 1.6571 - val_accuracy: 0.6667
# Epoch 51/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6554 - accuracy: 0.6778 - val_loss: 1.6545 - val_accuracy: 0.6678
# Epoch 52/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6508 - accuracy: 0.6858 - val_loss: 1.6518 - val_accuracy: 0.6689
# Epoch 53/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6479 - accuracy: 0.6858 - val_loss: 1.6492 - val_accuracy: 0.6699
# Epoch 54/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6462 - accuracy: 0.6853 - val_loss: 1.6466 - val_accuracy: 0.6710
# Epoch 55/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6452 - accuracy: 0.6828 - val_loss: 1.6440 - val_accuracy: 0.6720
# Epoch 56/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6388 - accuracy: 0.6904 - val_loss: 1.6413 - val_accuracy: 0.6729
# Epoch 57/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6387 - accuracy: 0.6887 - val_loss: 1.6387 - val_accuracy: 0.6739
# Epoch 58/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6377 - accuracy: 0.6859 - val_loss: 1.6361 - val_accuracy: 0.6749
# Epoch 59/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6348 - accuracy: 0.6863 - val_loss: 1.6335 - val_accuracy: 0.6760
# Epoch 60/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6330 - accuracy: 0.6875 - val_loss: 1.6309 - val_accuracy: 0.6770
# Epoch 61/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6309 - accuracy: 0.6884 - val_loss: 1.6283 - val_accuracy: 0.6779
# Epoch 62/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6275 - accuracy: 0.6897 - val_loss: 1.6257 - val_accuracy: 0.6788
# Epoch 63/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6221 - accuracy: 0.6978 - val_loss: 1.6232 - val_accuracy: 0.6798
# Epoch 64/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.6229 - accuracy: 0.6927 - val_loss: 1.6206 - val_accuracy: 0.6807
# Epoch 65/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6209 - accuracy: 0.6913 - val_loss: 1.6180 - val_accuracy: 0.6817
# Epoch 66/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6158 - accuracy: 0.6950 - val_loss: 1.6155 - val_accuracy: 0.6826
# Epoch 67/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6151 - accuracy: 0.6954 - val_loss: 1.6129 - val_accuracy: 0.6834
# Epoch 68/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6122 - accuracy: 0.6970 - val_loss: 1.6103 - val_accuracy: 0.6840
# Epoch 69/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6117 - accuracy: 0.6945 - val_loss: 1.6078 - val_accuracy: 0.6848
# Epoch 70/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6080 - accuracy: 0.6952 - val_loss: 1.6053 - val_accuracy: 0.6856
# Epoch 71/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6065 - accuracy: 0.6924 - val_loss: 1.6028 - val_accuracy: 0.6865
# Epoch 72/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6029 - accuracy: 0.6972 - val_loss: 1.6003 - val_accuracy: 0.6874
# Epoch 73/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.6032 - accuracy: 0.6966 - val_loss: 1.5978 - val_accuracy: 0.6885
# Epoch 74/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5970 - accuracy: 0.7005 - val_loss: 1.5953 - val_accuracy: 0.6897
# Epoch 75/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5946 - accuracy: 0.7016 - val_loss: 1.5928 - val_accuracy: 0.6910
# Epoch 76/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5922 - accuracy: 0.7026 - val_loss: 1.5904 - val_accuracy: 0.6924
# Epoch 77/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5909 - accuracy: 0.7017 - val_loss: 1.5880 - val_accuracy: 0.6939
# Epoch 78/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5887 - accuracy: 0.7016 - val_loss: 1.5856 - val_accuracy: 0.6953
# Epoch 79/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5864 - accuracy: 0.7024 - val_loss: 1.5832 - val_accuracy: 0.6970
# Epoch 80/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5845 - accuracy: 0.7037 - val_loss: 1.5808 - val_accuracy: 0.6989
# Epoch 81/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5823 - accuracy: 0.7053 - val_loss: 1.5784 - val_accuracy: 0.7008
# Epoch 82/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5817 - accuracy: 0.7030 - val_loss: 1.5761 - val_accuracy: 0.7030
# Epoch 83/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5787 - accuracy: 0.7035 - val_loss: 1.5737 - val_accuracy: 0.7054
# Epoch 84/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.5768 - accuracy: 0.7029 - val_loss: 1.5714 - val_accuracy: 0.7074
# Epoch 85/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5740 - accuracy: 0.7074 - val_loss: 1.5691 - val_accuracy: 0.7093
# Epoch 86/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5709 - accuracy: 0.7087 - val_loss: 1.5668 - val_accuracy: 0.7108
# Epoch 87/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5694 - accuracy: 0.7086 - val_loss: 1.5645 - val_accuracy: 0.7120
# Epoch 88/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5670 - accuracy: 0.7082 - val_loss: 1.5623 - val_accuracy: 0.7128
# Epoch 89/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5646 - accuracy: 0.7104 - val_loss: 1.5600 - val_accuracy: 0.7136
# Epoch 90/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5636 - accuracy: 0.7093 - val_loss: 1.5578 - val_accuracy: 0.7143
# Epoch 91/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5591 - accuracy: 0.7121 - val_loss: 1.5556 - val_accuracy: 0.7148
# Epoch 92/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5564 - accuracy: 0.7141 - val_loss: 1.5534 - val_accuracy: 0.7154
# Epoch 93/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5552 - accuracy: 0.7121 - val_loss: 1.5513 - val_accuracy: 0.7159
# Epoch 94/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5545 - accuracy: 0.7114 - val_loss: 1.5491 - val_accuracy: 0.7163
# Epoch 95/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5506 - accuracy: 0.7150 - val_loss: 1.5470 - val_accuracy: 0.7167
# Epoch 96/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5493 - accuracy: 0.7136 - val_loss: 1.5449 - val_accuracy: 0.7170
# Epoch 97/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.5488 - accuracy: 0.7126 - val_loss: 1.5428 - val_accuracy: 0.7173
# Epoch 98/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5467 - accuracy: 0.7133 - val_loss: 1.5407 - val_accuracy: 0.7176
# Epoch 99/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5432 - accuracy: 0.7130 - val_loss: 1.5386 - val_accuracy: 0.7179
# Epoch 100/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5418 - accuracy: 0.7158 - val_loss: 1.5365 - val_accuracy: 0.7181
# Epoch 101/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5393 - accuracy: 0.7159 - val_loss: 1.5345 - val_accuracy: 0.7184
# Epoch 102/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5373 - accuracy: 0.7158 - val_loss: 1.5325 - val_accuracy: 0.7187
# Epoch 103/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5356 - accuracy: 0.7166 - val_loss: 1.5304 - val_accuracy: 0.7191
# Epoch 104/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5322 - accuracy: 0.7219 - val_loss: 1.5284 - val_accuracy: 0.7195
# Epoch 105/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5318 - accuracy: 0.7181 - val_loss: 1.5264 - val_accuracy: 0.7199
# Epoch 106/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5287 - accuracy: 0.7194 - val_loss: 1.5245 - val_accuracy: 0.7203
# Epoch 107/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.5276 - accuracy: 0.7194 - val_loss: 1.5225 - val_accuracy: 0.7207
# Epoch 108/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5264 - accuracy: 0.7183 - val_loss: 1.5205 - val_accuracy: 0.7211
# Epoch 109/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.5237 - accuracy: 0.7187 - val_loss: 1.5186 - val_accuracy: 0.7215
# Epoch 110/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5220 - accuracy: 0.7173 - val_loss: 1.5167 - val_accuracy: 0.7218
# Epoch 111/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5205 - accuracy: 0.7194 - val_loss: 1.5147 - val_accuracy: 0.7222
# Epoch 112/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.5179 - accuracy: 0.7197 - val_loss: 1.5128 - val_accuracy: 0.7225
# Epoch 113/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5168 - accuracy: 0.7198 - val_loss: 1.5109 - val_accuracy: 0.7229
# Epoch 114/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5157 - accuracy: 0.7189 - val_loss: 1.5090 - val_accuracy: 0.7232
# Epoch 115/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5138 - accuracy: 0.7201 - val_loss: 1.5071 - val_accuracy: 0.7235
# Epoch 116/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5077 - accuracy: 0.7226 - val_loss: 1.5052 - val_accuracy: 0.7238
# Epoch 117/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5098 - accuracy: 0.7197 - val_loss: 1.5033 - val_accuracy: 0.7241
# Epoch 118/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5080 - accuracy: 0.7215 - val_loss: 1.5015 - val_accuracy: 0.7242
# Epoch 119/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5056 - accuracy: 0.7232 - val_loss: 1.4996 - val_accuracy: 0.7244
# Epoch 120/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5043 - accuracy: 0.7234 - val_loss: 1.4977 - val_accuracy: 0.7246
# Epoch 121/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.5003 - accuracy: 0.7240 - val_loss: 1.4959 - val_accuracy: 0.7248
# Epoch 122/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.5009 - accuracy: 0.7204 - val_loss: 1.4940 - val_accuracy: 0.7249
# Epoch 123/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4965 - accuracy: 0.7243 - val_loss: 1.4922 - val_accuracy: 0.7251
# Epoch 124/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4948 - accuracy: 0.7259 - val_loss: 1.4903 - val_accuracy: 0.7253
# Epoch 125/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4929 - accuracy: 0.7251 - val_loss: 1.4885 - val_accuracy: 0.7256
# Epoch 126/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4914 - accuracy: 0.7221 - val_loss: 1.4867 - val_accuracy: 0.7259
# Epoch 127/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4903 - accuracy: 0.7243 - val_loss: 1.4849 - val_accuracy: 0.7261
# Epoch 128/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4889 - accuracy: 0.7217 - val_loss: 1.4830 - val_accuracy: 0.7263
# Epoch 129/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4857 - accuracy: 0.7264 - val_loss: 1.4812 - val_accuracy: 0.7264
# Epoch 130/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4852 - accuracy: 0.7239 - val_loss: 1.4794 - val_accuracy: 0.7265
# Epoch 131/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4814 - accuracy: 0.7254 - val_loss: 1.4776 - val_accuracy: 0.7268
# Epoch 132/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4808 - accuracy: 0.7242 - val_loss: 1.4758 - val_accuracy: 0.7269
# Epoch 133/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4800 - accuracy: 0.7252 - val_loss: 1.4740 - val_accuracy: 0.7270
# Epoch 134/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4774 - accuracy: 0.7253 - val_loss: 1.4722 - val_accuracy: 0.7272
# Epoch 135/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4759 - accuracy: 0.7265 - val_loss: 1.4705 - val_accuracy: 0.7274
# Epoch 136/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4760 - accuracy: 0.7221 - val_loss: 1.4687 - val_accuracy: 0.7275
# Epoch 137/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.4752 - accuracy: 0.7221 - val_loss: 1.4670 - val_accuracy: 0.7277
# Epoch 138/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4719 - accuracy: 0.7227 - val_loss: 1.4652 - val_accuracy: 0.7277
# Epoch 139/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4682 - accuracy: 0.7251 - val_loss: 1.4635 - val_accuracy: 0.7279
# Epoch 140/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4664 - accuracy: 0.7278 - val_loss: 1.4617 - val_accuracy: 0.7280
# Epoch 141/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4662 - accuracy: 0.7246 - val_loss: 1.4600 - val_accuracy: 0.7281
# Epoch 142/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4637 - accuracy: 0.7269 - val_loss: 1.4582 - val_accuracy: 0.7282
# Epoch 143/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4623 - accuracy: 0.7246 - val_loss: 1.4565 - val_accuracy: 0.7285
# Epoch 144/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.4615 - accuracy: 0.7256 - val_loss: 1.4548 - val_accuracy: 0.7286
# Epoch 145/400
# 1/1 [==============================] - 6s 6s/step - loss: 1
400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2921 - accuracy: 0.7344 - val_loss: 1.2854 - val_accuracy: 0.7362
# Epoch 261/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2895 - accuracy: 0.7369 - val_loss: 1.2842 - val_accuracy: 0.7362
# Epoch 262/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2847 - accuracy: 0.7390 - val_loss: 1.2829 - val_accuracy: 0.7362
# Epoch 263/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2896 - accuracy: 0.7333 - val_loss: 1.2816 - val_accuracy: 0.7362
# Epoch 264/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2872 - accuracy: 0.7342 - val_loss: 1.2804 - val_accuracy: 0.7363
# Epoch 265/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2851 - accuracy: 0.7365 - val_loss: 1.2791 - val_accuracy: 0.7363
# Epoch 266/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2853 - accuracy: 0.7329 - val_loss: 1.2779 - val_accuracy: 0.7363
# Epoch 267/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2846 - accuracy: 0.7341 - val_loss: 1.2767 - val_accuracy: 0.7363
# Epoch 268/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2819 - accuracy: 0.7349 - val_loss: 1.2754 - val_accuracy: 0.7363
# Epoch 269/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2801 - accuracy: 0.7347 - val_loss: 1.2742 - val_accuracy: 0.7363
# Epoch 270/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2776 - accuracy: 0.7361 - val_loss: 1.2730 - val_accuracy: 0.7363
# Epoch 271/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2782 - accuracy: 0.7347 - val_loss: 1.2718 - val_accuracy: 0.7364
# Epoch 272/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2769 - accuracy: 0.7355 - val_loss: 1.2706 - val_accuracy: 0.7364
# Epoch 273/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.2752 - accuracy: 0.7358 - val_loss: 1.2694 - val_accuracy: 0.7364
# Epoch 274/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.2730 - accuracy: 0.7369 - val_loss: 1.2682 - val_accuracy: 0.7364
# Epoch 275/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2761 - accuracy: 0.7329 - val_loss: 1.2669 - val_accuracy: 0.7364
# Epoch 276/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2715 - accuracy: 0.7368 - val_loss: 1.2658 - val_accuracy: 0.7364
# Epoch 277/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2719 - accuracy: 0.7337 - val_loss: 1.2646 - val_accuracy: 0.7364
# Epoch 278/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2689 - accuracy: 0.7375 - val_loss: 1.2634 - val_accuracy: 0.7364
# Epoch 279/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2687 - accuracy: 0.7364 - val_loss: 1.2622 - val_accuracy: 0.7364
# Epoch 280/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2650 - accuracy: 0.7370 - val_loss: 1.2610 - val_accuracy: 0.7364
# Epoch 281/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2629 - accuracy: 0.7381 - val_loss: 1.2599 - val_accuracy: 0.7364
# Epoch 282/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2636 - accuracy: 0.7368 - val_loss: 1.2587 - val_accuracy: 0.7364
# Epoch 283/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2621 - accuracy: 0.7372 - val_loss: 1.2575 - val_accuracy: 0.7364
# Epoch 284/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2638 - accuracy: 0.7347 - val_loss: 1.2563 - val_accuracy: 0.7364
# Epoch 285/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2602 - accuracy: 0.7365 - val_loss: 1.2551 - val_accuracy: 0.7364
# Epoch 286/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.2587 - accuracy: 0.7365 - val_loss: 1.2539 - val_accuracy: 0.7365
# Epoch 287/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2569 - accuracy: 0.7371 - val_loss: 1.2527 - val_accuracy: 0.7365
# Epoch 288/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2562 - accuracy: 0.7368 - val_loss: 1.2515 - val_accuracy: 0.7365
# Epoch 289/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2536 - accuracy: 0.7378 - val_loss: 1.2503 - val_accuracy: 0.7365
# Epoch 290/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2536 - accuracy: 0.7374 - val_loss: 1.2490 - val_accuracy: 0.7366
# Epoch 291/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2509 - accuracy: 0.7376 - val_loss: 1.2478 - val_accuracy: 0.7366
# Epoch 292/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2540 - accuracy: 0.7340 - val_loss: 1.2466 - val_accuracy: 0.7367
# Epoch 293/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2515 - accuracy: 0.7366 - val_loss: 1.2454 - val_accuracy: 0.7367
# Epoch 294/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2519 - accuracy: 0.7348 - val_loss: 1.2442 - val_accuracy: 0.7367
# Epoch 295/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2469 - accuracy: 0.7384 - val_loss: 1.2430 - val_accuracy: 0.7368
# Epoch 296/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2496 - accuracy: 0.7341 - val_loss: 1.2419 - val_accuracy: 0.7368
# Epoch 297/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.2450 - accuracy: 0.7368 - val_loss: 1.2407 - val_accuracy: 0.7368
# Epoch 298/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2455 - accuracy: 0.7353 - val_loss: 1.2395 - val_accuracy: 0.7369
# Epoch 299/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2414 - accuracy: 0.7381 - val_loss: 1.2383 - val_accuracy: 0.7369
# Epoch 300/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2408 - accuracy: 0.7389 - val_loss: 1.2371 - val_accuracy: 0.7370
# Epoch 301/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2415 - accuracy: 0.7357 - val_loss: 1.2360 - val_accuracy: 0.7370
# Epoch 302/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2405 - accuracy: 0.7355 - val_loss: 1.2348 - val_accuracy: 0.7371
# Epoch 303/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2374 - accuracy: 0.7381 - val_loss: 1.2336 - val_accuracy: 0.7371
# Epoch 304/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2383 - accuracy: 0.7362 - val_loss: 1.2324 - val_accuracy: 0.7372
# Epoch 305/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2349 - accuracy: 0.7404 - val_loss: 1.2312 - val_accuracy: 0.7372
# Epoch 306/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2327 - accuracy: 0.7398 - val_loss: 1.2301 - val_accuracy: 0.7373
# Epoch 307/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2344 - accuracy: 0.7373 - val_loss: 1.2289 - val_accuracy: 0.7373
# Epoch 308/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2308 - accuracy: 0.7393 - val_loss: 1.2278 - val_accuracy: 0.7373
# Epoch 309/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2327 - accuracy: 0.7374 - val_loss: 1.2266 - val_accuracy: 0.7374
# Epoch 310/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2301 - accuracy: 0.7389 - val_loss: 1.2255 - val_accuracy: 0.7374
# Epoch 311/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2289 - accuracy: 0.7384 - val_loss: 1.2244 - val_accuracy: 0.7374
# Epoch 312/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.2266 - accuracy: 0.7389 - val_loss: 1.2232 - val_accuracy: 0.7374
# Epoch 313/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2250 - accuracy: 0.7404 - val_loss: 1.2221 - val_accuracy: 0.7374
# Epoch 314/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2254 - accuracy: 0.7401 - val_loss: 1.2210 - val_accuracy: 0.7374
# Epoch 315/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2244 - accuracy: 0.7386 - val_loss: 1.2199 - val_accuracy: 0.7374
# Epoch 316/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2238 - accuracy: 0.7390 - val_loss: 1.2188 - val_accuracy: 0.7374
# Epoch 317/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.2216 - accuracy: 0.7400 - val_loss: 1.2176 - val_accuracy: 0.7375
# Epoch 318/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2197 - accuracy: 0.7397 - val_loss: 1.2165 - val_accuracy: 0.7375
# Epoch 319/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2218 - accuracy: 0.7381 - val_loss: 1.2154 - val_accuracy: 0.7375
# Epoch 320/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2193 - accuracy: 0.7365 - val_loss: 1.2143 - val_accuracy: 0.7375
# Epoch 321/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2190 - accuracy: 0.7379 - val_loss: 1.2132 - val_accuracy: 0.7375
# Epoch 322/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2174 - accuracy: 0.7387 - val_loss: 1.2121 - val_accuracy: 0.7375
# Epoch 323/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2126 - accuracy: 0.7416 - val_loss: 1.2110 - val_accuracy: 0.7375
# Epoch 324/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2148 - accuracy: 0.7392 - val_loss: 1.2099 - val_accuracy: 0.7376
# Epoch 325/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2120 - accuracy: 0.7399 - val_loss: 1.2088 - val_accuracy: 0.7375
# Epoch 326/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2104 - accuracy: 0.7409 - val_loss: 1.2076 - val_accuracy: 0.7375
# Epoch 327/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2104 - accuracy: 0.7382 - val_loss: 1.2066 - val_accuracy: 0.7375
# Epoch 328/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2104 - accuracy: 0.7381 - val_loss: 1.2055 - val_accuracy: 0.7375
# Epoch 329/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2088 - accuracy: 0.7391 - val_loss: 1.2044 - val_accuracy: 0.7375
# Epoch 330/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.2102 - accuracy: 0.7357 - val_loss: 1.2034 - val_accuracy: 0.7375
# Epoch 331/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2042 - accuracy: 0.7400 - val_loss: 1.2023 - val_accuracy: 0.7375
# Epoch 332/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.2053 - accuracy: 0.7405 - val_loss: 1.2012 - val_accuracy: 0.7375
# Epoch 333/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2031 - accuracy: 0.7399 - val_loss: 1.2001 - val_accuracy: 0.7376
# Epoch 334/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2017 - accuracy: 0.7399 - val_loss: 1.1990 - val_accuracy: 0.7376
# Epoch 335/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2009 - accuracy: 0.7389 - val_loss: 1.1979 - val_accuracy: 0.7377
# Epoch 336/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.2008 - accuracy: 0.7389 - val_loss: 1.1968 - val_accuracy: 0.7377
# Epoch 337/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1985 - accuracy: 0.7400 - val_loss: 1.1957 - val_accuracy: 0.7377
# Epoch 338/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1988 - accuracy: 0.7387 - val_loss: 1.1946 - val_accuracy: 0.7377
# Epoch 339/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1989 - accuracy: 0.7378 - val_loss: 1.1935 - val_accuracy: 0.7377
# Epoch 340/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1974 - accuracy: 0.7390 - val_loss: 1.1924 - val_accuracy: 0.7378
# Epoch 341/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1951 - accuracy: 0.7393 - val_loss: 1.1913 - val_accuracy: 0.7378
# Epoch 342/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1966 - accuracy: 0.7377 - val_loss: 1.1902 - val_accuracy: 0.7378
# Epoch 343/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1933 - accuracy: 0.7388 - val_loss: 1.1891 - val_accuracy: 0.7379
# Epoch 344/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1937 - accuracy: 0.7379 - val_loss: 1.1881 - val_accuracy: 0.7379
# Epoch 345/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1900 - accuracy: 0.7408 - val_loss: 1.1870 - val_accuracy: 0.7380
# Epoch 346/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1926 - accuracy: 0.7375 - val_loss: 1.1860 - val_accuracy: 0.7380
# Epoch 347/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1877 - accuracy: 0.7405 - val_loss: 1.1849 - val_accuracy: 0.7380
# Epoch 348/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1881 - accuracy: 0.7391 - val_loss: 1.1839 - val_accuracy: 0.7380
# Epoch 349/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1835 - accuracy: 0.7426 - val_loss: 1.1828 - val_accuracy: 0.7380
# Epoch 350/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1854 - accuracy: 0.7414 - val_loss: 1.1818 - val_accuracy: 0.7380
# Epoch 351/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1842 - accuracy: 0.7404 - val_loss: 1.1807 - val_accuracy: 0.7379
# Epoch 352/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1807 - accuracy: 0.7417 - val_loss: 1.1797 - val_accuracy: 0.7380
# Epoch 353/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1819 - accuracy: 0.7402 - val_loss: 1.1786 - val_accuracy: 0.7380
# Epoch 354/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1792 - accuracy: 0.7422 - val_loss: 1.1776 - val_accuracy: 0.7380
# Epoch 355/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1833 - accuracy: 0.7381 - val_loss: 1.1765 - val_accuracy: 0.7380
# Epoch 356/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1794 - accuracy: 0.7407 - val_loss: 1.1755 - val_accuracy: 0.7380
# Epoch 357/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1840 - accuracy: 0.7351 - val_loss: 1.1745 - val_accuracy: 0.7380
# Epoch 358/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1763 - accuracy: 0.7401 - val_loss: 1.1734 - val_accuracy: 0.7380
# Epoch 359/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1724 - accuracy: 0.7423 - val_loss: 1.1724 - val_accuracy: 0.7380
# Epoch 360/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1781 - accuracy: 0.7379 - val_loss: 1.1714 - val_accuracy: 0.7380
# Epoch 361/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1726 - accuracy: 0.7403 - val_loss: 1.1703 - val_accuracy: 0.7380
# Epoch 362/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1699 - accuracy: 0.7423 - val_loss: 1.1693 - val_accuracy: 0.7381
# Epoch 363/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1746 - accuracy: 0.7382 - val_loss: 1.1683 - val_accuracy: 0.7381
# Epoch 364/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1721 - accuracy: 0.7397 - val_loss: 1.1672 - val_accuracy: 0.7381
# Epoch 365/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1681 - accuracy: 0.7417 - val_loss: 1.1662 - val_accuracy: 0.7381
# Epoch 366/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1670 - accuracy: 0.7430 - val_loss: 1.1652 - val_accuracy: 0.7381
# Epoch 367/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1680 - accuracy: 0.7398 - val_loss: 1.1642 - val_accuracy: 0.7382
# Epoch 368/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1649 - accuracy: 0.7421 - val_loss: 1.1631 - val_accuracy: 0.7382
# Epoch 369/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1640 - accuracy: 0.7419 - val_loss: 1.1621 - val_accuracy: 0.7382
# Epoch 370/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1631 - accuracy: 0.7420 - val_loss: 1.1611 - val_accuracy: 0.7382
# Epoch 371/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1613 - accuracy: 0.7417 - val_loss: 1.1601 - val_accuracy: 0.7382
# Epoch 372/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1629 - accuracy: 0.7398 - val_loss: 1.1591 - val_accuracy: 0.7382
# Epoch 373/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1600 - accuracy: 0.7418 - val_loss: 1.1581 - val_accuracy: 0.7383
# Epoch 374/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1635 - accuracy: 0.7372 - val_loss: 1.1571 - val_accuracy: 0.7383
# Epoch 375/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1570 - accuracy: 0.7426 - val_loss: 1.1561 - val_accuracy: 0.7383
# Epoch 376/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1598 - accuracy: 0.7401 - val_loss: 1.1551 - val_accuracy: 0.7383
# Epoch 377/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1598 - accuracy: 0.7387 - val_loss: 1.1542 - val_accuracy: 0.7382
# Epoch 378/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1531 - accuracy: 0.7429 - val_loss: 1.1532 - val_accuracy: 0.7382
# Epoch 379/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1554 - accuracy: 0.7411 - val_loss: 1.1522 - val_accuracy: 0.7382
# Epoch 380/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1537 - accuracy: 0.7427 - val_loss: 1.1513 - val_accuracy: 0.7381
# Epoch 381/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1555 - accuracy: 0.7393 - val_loss: 1.1503 - val_accuracy: 0.7382
# Epoch 382/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1509 - accuracy: 0.7419 - val_loss: 1.1493 - val_accuracy: 0.7381
# Epoch 383/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1509 - accuracy: 0.7406 - val_loss: 1.1483 - val_accuracy: 0.7381
# Epoch 384/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1511 - accuracy: 0.7405 - val_loss: 1.1473 - val_accuracy: 0.7381
# Epoch 385/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1475 - accuracy: 0.7422 - val_loss: 1.1464 - val_accuracy: 0.7381
# Epoch 386/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1501 - accuracy: 0.7391 - val_loss: 1.1454 - val_accuracy: 0.7381
# Epoch 387/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1462 - accuracy: 0.7414 - val_loss: 1.1444 - val_accuracy: 0.7381
# Epoch 388/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1444 - accuracy: 0.7411 - val_loss: 1.1434 - val_accuracy: 0.7380
# Epoch 389/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1450 - accuracy: 0.7409 - val_loss: 1.1424 - val_accuracy: 0.7380
# Epoch 390/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1421 - accuracy: 0.7413 - val_loss: 1.1414 - val_accuracy: 0.7381
# Epoch 391/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1411 - accuracy: 0.7429 - val_loss: 1.1404 - val_accuracy: 0.7381
# Epoch 392/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1429 - accuracy: 0.7404 - val_loss: 1.1394 - val_accuracy: 0.7381
# Epoch 393/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1423 - accuracy: 0.7391 - val_loss: 1.1384 - val_accuracy: 0.7381
# Epoch 394/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1406 - accuracy: 0.7409 - val_loss: 1.1374 - val_accuracy: 0.7382
# Epoch 395/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1383 - accuracy: 0.7410 - val_loss: 1.1364 - val_accuracy: 0.7382
# Epoch 396/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1364 - accuracy: 0.7416 - val_loss: 1.1354 - val_accuracy: 0.7383
# Epoch 397/400
# 1/1 [==============================] - 6s 6s/step - loss: 1.1367 - accuracy: 0.7398 - val_loss: 1.1344 - val_accuracy: 0.7383
# Epoch 398/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1339 - accuracy: 0.7415 - val_loss: 1.1333 - val_accuracy: 0.7384
# Epoch 399/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1343 - accuracy: 0.7417 - val_loss: 1.1323 - val_accuracy: 0.7385
# Epoch 400/400
# 1/1 [==============================] - 5s 5s/step - loss: 1.1323 - accuracy: 0.7427 - val_loss: 1.1313 - val_accuracy: 0.7386

# %%
PlotHistory(transfer_model_history, 'loss')

# %%
PlotHistory(transfer_model_history, 'loss')

# %%
pred_test_f3 = transfer_model_unet.predict(x_train_f3)
print(pred_test_f3.shape)
pred_mask_f3 = tf.argmax(pred_test_f3, axis=-1)
  # # pred_mask becomes [IMG_SIZE, IMG_SIZE]
  # # but matplotlib needs [IMG_SIZE, IMG_SIZE, 1]
pred_mask_f3 = tf.expand_dims(pred_mask_f3, axis=-1)
print(pred_mask_f3.shape)
# Out:
# WARNING:tensorflow:6 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2830842d40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (32, 128, 128, 7)
# (32, 128, 128, 1)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(pred_mask_f3[4, :, :, 0])
ax[0].set_xlabel('X (km)')
ax[0].set_ylabel('Time (s)')
ax[0].set_title('Predicted Facies')
ax[1].imshow(y_train_f3[4, :, :])
ax[1].set_xlabel('X (km)')
ax[1].set_ylabel('Time (s)')
ax[1].set_title('Predicted Facies')
fig.suptitle('Transfer Learning Prediction with Training (Netherlands F3)')

# %% [markdown]
# # Now knowing the information from the Parihaka is overbearing in the transfer learning, we need to fine tune with transfer learning

# %%
base_model = tf.keras.models.load_model('/content/drive/MyDrive/Dataset /fixed_model_unet_1.h5')

# %%
for i, layer in enumerate(base_model.layers):
   print(i, layer.name)
# Out:
# 0 input_1
# 1 conv2d
# 2 batch_normalization
# 3 conv2d_1
# 4 batch_normalization_1
# 5 activation
# 6 max_pooling2d
# 7 dropout
# 8 conv2d_2
# 9 batch_normalization_2
# 10 conv2d_3
# 11 batch_normalization_3
# 12 activation_1
# 13 max_pooling2d_1
# 14 dropout_1
# 15 conv2d_4
# 16 batch_normalization_4
# 17 conv2d_5
# 18 batch_normalization_5
# 19 activation_2
# 20 max_pooling2d_2
# 21 dropout_2
# 22 conv2d_6
# 23 batch_normalization_6
# 24 conv2d_7
# 25 batch_normalization_7
# 26 activation_3
# 27 max_pooling2d_3
# 28 dropout_3
# 29 conv2d_8
# 30 batch_normalization_8
# 31 conv2d_9
# 32 batch_normalization_9
# 33 activation_4
# 34 up_sampling2d
# 35 conv2d_10
# 36 concatenate
# 37 dropout_4
# 38 conv2d_11
# 39 batch_normalization_10
# 40 conv2d_12
# 41 batch_normalization_11
# 42 activation_5
# 43 up_sampling2d_1
# 44 conv2d_13
# 45 concatenate_1
# 46 dropout_5
# 47 conv2d_14
# 48 batch_normalization_12
# 49 conv2d_15
# 50 batch_normalization_13
# 51 activation_6
# 52 up_sampling2d_2
# 53 conv2d_16
# 54 concatenate_2
# 55 dropout_6
# 56 conv2d_17
# 57 batch_normalization_14
# 58 conv2d_18
# 59 batch_normalization_15
# 60 activation_7
# 61 up_sampling2d_3
# 62 conv2d_19
# 63 concatenate_3
# 64 dropout_7
# 65 conv2d_20
# 66 batch_normalization_16
# 67 conv2d_21
# 68 batch_normalization_17
# 69 activation_8
# 70 conv2d_22

# %%
for layer in base_model.layers[:69]:
   layer.trainable = False
for layer in base_model.layers[69:]:
   layer.trainable = True

# base_model.trainable = False

for layer in base_model.layers:
    if "BatchNormalization" in layer.__class__.__name__:
        layer.trainable = True

# %%
N_CLASSES_F3 = 7
transfer_out = base_model.output
# transfer_out = Dense(1024, activation='relu')(base_model.output)
transfer_out = Dropout(0.2, name='drop_transfer')(transfer_out)
transfer_out = tf.keras.layers.Conv2D(N_CLASSES_F3, 1, activation = 'softmax', name='transfer')(transfer_out)

# %%
transfer_model_unet = tf.keras.Model(inputs=base_model.input, outputs=transfer_out)

# %%
def dice_coef(y_true, y_pred, smooth=1e-7):
    '''
    Dice coefficient for 10 categories. Ignores background pixel label 0
    Pass to model as metric during compile statement
    '''
    y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=7))
    y_pred_f = K.flatten(y_pred)
    intersect = K.sum(y_true_f * y_pred_f, axis=-1)
    denom = K.sum(y_true_f + y_pred_f, axis=-1)
    return K.mean((2. * intersect / (denom + smooth)))

def PlotHistory(_model, feature, start_epoch = 0, path_file = None):
    val = "val_" + feature
    
    plt.xlabel('Epoch Number - ' + str(start_epoch))
    plt.ylabel(feature)
    plt.plot(_model.history[feature][start_epoch:])
    plt.plot(_model.history[val][start_epoch:])
    plt.title(val)
    plt.legend(["train_"+feature, val])

# %%
initial_learning_rate = 0.1
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate, decay_steps=20, decay_rate=0.94, staircase=True)

#lr_schedule = 0.0001

transfer_model_unet.compile(optimizer=Adam(learning_rate=lr_schedule), loss = tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy', dice_coef])

#x_split, x_test_f3, y_split, y_test_f3 = train_test_split(training_img_data_f3, training_label_data_f3,test_size=0.985, shuffle= False) #take out of the bunch of the data
x_train_f3, x_test_f3_throw, y_train_f3, y_test_f3_throw = train_test_split(training_img_data_f3, training_label_data_f3,test_size=0.985, shuffle= False) #take out of the bunch of the data

#x_train_f3, x_val_f3_throw, y_train_f3, y_val_f3_throw = train_test_split(x_split, y_split, test_size=0, shuffle= False) # split train and validation 

x_val_f3, x_test_f3, y_val_f3, y_test_f3 = train_test_split(test1_img_data_f3, test1_label_data_f3,test_size=0.995, shuffle= False) #take out of the bunch of the data

# %%
fig, ax = plt.subplots(1,4, figsize=(20,20))

ax[0].imshow(x_train_f3[0, :, :, 0])
ax[0].set_xlabel('X (km)')
ax[0].set_ylabel('Time (s)')
ax[0].set_title('Seismic Data (Train Example)')
ax[1].imshow(y_train_f3[0, :, :])
ax[1].set_xlabel('X (km)')
ax[1].set_ylabel('Time (s)')
ax[1].set_title('True Facies (Labels)')
ax[2].imshow(x_val_f3[0, :, :, 0])
ax[2].set_xlabel('X (km)')
ax[2].set_ylabel('Time (s)')
ax[2].set_title('Seismic Data (Validation Example)')
ax[3].imshow(y_val_f3[0, :, :])
ax[3].set_xlabel('X (km)')
ax[3].set_ylabel('Time (s)')
ax[3].set_title('True Facies (Labels)')
# Out:
# Text(0.5, 1.0, 'True Facies (Labels)')

# %%
x_val_f3.shape
x_train_f3.shape
# Out:
# (6, 128, 128, 3)

# %%
model_path_transfer = "{}.h5".format('fixed_model_unet_1_transfer_tuned_1') #hdf5
checkpoint = ModelCheckpoint(model_path_transfer, monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only = False)
early_stop = EarlyStopping(monitor="val_loss",mode="min",patience=400)

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_images=True, update_freq='batch')

transfer_model_history = transfer_model_unet.fit(x_train_f3, y_train_f3, validation_data=(x_val_f3, y_val_f3), epochs=200, callbacks=[tensorboard_callback, early_stop])
#transfer_model_history = transfer_model_unet.fit(datagen_f3.flow(x_train_f3, y_train_f3), validation_data=(x_val_f3, y_val_f3), epochs=100, callbacks=[tensorboard_callback, early_stop])
# Out:
# Epoch 1/200
# 1/1 [==============================] - 26s 26s/step - loss: 1.9412 - accuracy: 0.0446 - dice_coef: 0.1487 - val_loss: 1.6416 - val_accuracy: 0.6914 - val_dice_coef: 0.1971
# Epoch 2/200
# 1/1 [==============================] - 4s 4s/step - loss: 1.6862 - accuracy: 0.4607 - dice_coef: 0.1905 - val_loss: 1.5926 - val_accuracy: 0.5359 - val_dice_coef: 0.2214
# Epoch 3/200
# 1/1 [==============================] - 4s 4s/step - loss: 1.4568 - accuracy: 0.6381 - dice_coef: 0.2542 - val_loss: 1.4876 - val_accuracy: 0.5662 - val_dice_coef: 0.2628
# Epoch 4/200
# 1/1 [==============================] - 4s 4s/step - loss: 1.3434 - accuracy: 0.6508 - dice_coef: 0.3031 - val_loss: 1.2398 - val_accuracy: 0.7173 - val_dice_coef: 0.3414
# Epoch 5/200
# 1/1 [==============================] - 4s 4s/step - loss: 1.2456 - accuracy: 0.6672 - dice_coef: 0.3498 - val_loss: 1.1271 - val_accuracy: 0.7465 - val_dice_coef: 0.3891
# Epoch 6/200
# 1/1 [==============================] - 4s 4s/step - loss: 1.1457 - accuracy: 0.6858 - dice_coef: 0.3957 - val_loss: 1.0431 - val_accuracy: 0.7549 - val_dice_coef: 0.4305
# Epoch 7/200
# 1/1 [==============================] - 4s 4s/step - loss: 1.0714 - accuracy: 0.6873 - dice_coef: 0.4336 - val_loss: 0.9912 - val_accuracy: 0.7580 - val_dice_coef: 0.4686
# Epoch 8/200
# 1/1 [==============================] - 4s 4s/step - loss: 1.0200 - accuracy: 0.6964 - dice_coef: 0.4716 - val_loss: 0.9523 - val_accuracy: 0.7546 - val_dice_coef: 0.4992
# Epoch 9/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.9661 - accuracy: 0.6997 - dice_coef: 0.5027 - val_loss: 0.9535 - val_accuracy: 0.7363 - val_dice_coef: 0.5156
# Epoch 10/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.9169 - accuracy: 0.7017 - dice_coef: 0.5252 - val_loss: 1.0126 - val_accuracy: 0.6952 - val_dice_coef: 0.5130
# Epoch 11/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.8915 - accuracy: 0.7012 - dice_coef: 0.5420 - val_loss: 1.0621 - val_accuracy: 0.6685 - val_dice_coef: 0.5139
# Epoch 12/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.8573 - accuracy: 0.7018 - dice_coef: 0.5578 - val_loss: 1.1820 - val_accuracy: 0.6564 - val_dice_coef: 0.4991
# Epoch 13/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.8279 - accuracy: 0.7039 - dice_coef: 0.5716 - val_loss: 1.1133 - val_accuracy: 0.6547 - val_dice_coef: 0.5278
# Epoch 14/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.7981 - accuracy: 0.7055 - dice_coef: 0.5869 - val_loss: 1.1073 - val_accuracy: 0.6544 - val_dice_coef: 0.5360
# Epoch 15/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.7760 - accuracy: 0.7071 - dice_coef: 0.5991 - val_loss: 1.1315 - val_accuracy: 0.6466 - val_dice_coef: 0.5348
# Epoch 16/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.7503 - accuracy: 0.7098 - dice_coef: 0.6089 - val_loss: 1.1884 - val_accuracy: 0.6328 - val_dice_coef: 0.5257
# Epoch 17/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.7339 - accuracy: 0.7085 - dice_coef: 0.6114 - val_loss: 1.2926 - val_accuracy: 0.6041 - val_dice_coef: 0.5030
# Epoch 18/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.7137 - accuracy: 0.7108 - dice_coef: 0.6160 - val_loss: 1.4099 - val_accuracy: 0.5703 - val_dice_coef: 0.4864
# Epoch 19/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.6864 - accuracy: 0.7153 - dice_coef: 0.6269 - val_loss: 1.4860 - val_accuracy: 0.5529 - val_dice_coef: 0.4786
# Epoch 20/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.6704 - accuracy: 0.7218 - dice_coef: 0.6395 - val_loss: 1.4506 - val_accuracy: 0.5518 - val_dice_coef: 0.4936
# Epoch 21/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.6515 - accuracy: 0.7455 - dice_coef: 0.6472 - val_loss: 1.3838 - val_accuracy: 0.5670 - val_dice_coef: 0.5124
# Epoch 22/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.6325 - accuracy: 0.7458 - dice_coef: 0.6531 - val_loss: 1.3758 - val_accuracy: 0.5709 - val_dice_coef: 0.5187
# Epoch 23/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.6177 - accuracy: 0.7489 - dice_coef: 0.6607 - val_loss: 1.4181 - val_accuracy: 0.5699 - val_dice_coef: 0.5206
# Epoch 24/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.6010 - accuracy: 0.7507 - dice_coef: 0.6730 - val_loss: 1.4524 - val_accuracy: 0.5671 - val_dice_coef: 0.5236
# Epoch 25/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.5902 - accuracy: 0.7546 - dice_coef: 0.6810 - val_loss: 1.5366 - val_accuracy: 0.5422 - val_dice_coef: 0.5077
# Epoch 26/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.5789 - accuracy: 0.7833 - dice_coef: 0.6824 - val_loss: 1.5805 - val_accuracy: 0.5536 - val_dice_coef: 0.5107
# Epoch 27/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.5660 - accuracy: 0.7890 - dice_coef: 0.6951 - val_loss: 1.5603 - val_accuracy: 0.5695 - val_dice_coef: 0.5248
# Epoch 28/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.5568 - accuracy: 0.7917 - dice_coef: 0.7021 - val_loss: 1.5076 - val_accuracy: 0.5840 - val_dice_coef: 0.5414
# Epoch 29/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.5415 - accuracy: 0.7932 - dice_coef: 0.7080 - val_loss: 1.5733 - val_accuracy: 0.5707 - val_dice_coef: 0.5324
# Epoch 30/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.5330 - accuracy: 0.7982 - dice_coef: 0.7097 - val_loss: 1.6315 - val_accuracy: 0.5786 - val_dice_coef: 0.5386
# Epoch 31/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.5145 - accuracy: 0.8051 - dice_coef: 0.7212 - val_loss: 1.6684 - val_accuracy: 0.5775 - val_dice_coef: 0.5407
# Epoch 32/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.5096 - accuracy: 0.8024 - dice_coef: 0.7224 - val_loss: 1.7130 - val_accuracy: 0.5721 - val_dice_coef: 0.5382
# Epoch 33/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.5034 - accuracy: 0.8043 - dice_coef: 0.7250 - val_loss: 1.7722 - val_accuracy: 0.5566 - val_dice_coef: 0.5238
# Epoch 34/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4987 - accuracy: 0.8088 - dice_coef: 0.7242 - val_loss: 1.8912 - val_accuracy: 0.5406 - val_dice_coef: 0.5087
# Epoch 35/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4826 - accuracy: 0.8145 - dice_coef: 0.7328 - val_loss: 1.9627 - val_accuracy: 0.5311 - val_dice_coef: 0.4997
# Epoch 36/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4806 - accuracy: 0.8139 - dice_coef: 0.7349 - val_loss: 1.9950 - val_accuracy: 0.5229 - val_dice_coef: 0.4928
# Epoch 37/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4750 - accuracy: 0.8144 - dice_coef: 0.7370 - val_loss: 1.9719 - val_accuracy: 0.5171 - val_dice_coef: 0.4900
# Epoch 38/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4643 - accuracy: 0.8168 - dice_coef: 0.7409 - val_loss: 1.9469 - val_accuracy: 0.5154 - val_dice_coef: 0.4910
# Epoch 39/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4676 - accuracy: 0.8139 - dice_coef: 0.7401 - val_loss: 2.0576 - val_accuracy: 0.4881 - val_dice_coef: 0.4738
# Epoch 40/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4575 - accuracy: 0.8199 - dice_coef: 0.7437 - val_loss: 2.1369 - val_accuracy: 0.4932 - val_dice_coef: 0.4799
# Epoch 41/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4557 - accuracy: 0.8231 - dice_coef: 0.7479 - val_loss: 2.1277 - val_accuracy: 0.5025 - val_dice_coef: 0.4871
# Epoch 42/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4492 - accuracy: 0.8214 - dice_coef: 0.7497 - val_loss: 2.2129 - val_accuracy: 0.4897 - val_dice_coef: 0.4763
# Epoch 43/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4443 - accuracy: 0.8227 - dice_coef: 0.7508 - val_loss: 2.2675 - val_accuracy: 0.4917 - val_dice_coef: 0.4793
# Epoch 44/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4503 - accuracy: 0.8217 - dice_coef: 0.7522 - val_loss: 2.2069 - val_accuracy: 0.5116 - val_dice_coef: 0.4977
# Epoch 45/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4394 - accuracy: 0.8199 - dice_coef: 0.7562 - val_loss: 2.1670 - val_accuracy: 0.5255 - val_dice_coef: 0.5104
# Epoch 46/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4386 - accuracy: 0.8223 - dice_coef: 0.7558 - val_loss: 2.1938 - val_accuracy: 0.5280 - val_dice_coef: 0.5130
# Epoch 47/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4313 - accuracy: 0.8257 - dice_coef: 0.7606 - val_loss: 2.2067 - val_accuracy: 0.5336 - val_dice_coef: 0.5206
# Epoch 48/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4250 - accuracy: 0.8278 - dice_coef: 0.7653 - val_loss: 2.2034 - val_accuracy: 0.5370 - val_dice_coef: 0.5241
# Epoch 49/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4236 - accuracy: 0.8239 - dice_coef: 0.7643 - val_loss: 2.2216 - val_accuracy: 0.5329 - val_dice_coef: 0.5202
# Epoch 50/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4236 - accuracy: 0.8226 - dice_coef: 0.7612 - val_loss: 2.2384 - val_accuracy: 0.5351 - val_dice_coef: 0.5234
# Epoch 51/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4164 - accuracy: 0.8262 - dice_coef: 0.7672 - val_loss: 2.2492 - val_accuracy: 0.5408 - val_dice_coef: 0.5290
# Epoch 52/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4149 - accuracy: 0.8233 - dice_coef: 0.7686 - val_loss: 2.2571 - val_accuracy: 0.5438 - val_dice_coef: 0.5315
# Epoch 53/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4116 - accuracy: 0.8247 - dice_coef: 0.7710 - val_loss: 2.2657 - val_accuracy: 0.5415 - val_dice_coef: 0.5299
# Epoch 54/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4128 - accuracy: 0.8246 - dice_coef: 0.7713 - val_loss: 2.2797 - val_accuracy: 0.5421 - val_dice_coef: 0.5301
# Epoch 55/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4057 - accuracy: 0.8281 - dice_coef: 0.7766 - val_loss: 2.2839 - val_accuracy: 0.5452 - val_dice_coef: 0.5340
# Epoch 56/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.4029 - accuracy: 0.8264 - dice_coef: 0.7788 - val_loss: 2.2908 - val_accuracy: 0.5447 - val_dice_coef: 0.5345
# Epoch 57/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3995 - accuracy: 0.8273 - dice_coef: 0.7797 - val_loss: 2.3049 - val_accuracy: 0.5447 - val_dice_coef: 0.5332
# Epoch 58/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3963 - accuracy: 0.8292 - dice_coef: 0.7819 - val_loss: 2.3172 - val_accuracy: 0.5419 - val_dice_coef: 0.5312
# Epoch 59/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3980 - accuracy: 0.8277 - dice_coef: 0.7809 - val_loss: 2.3299 - val_accuracy: 0.5409 - val_dice_coef: 0.5309
# Epoch 60/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3906 - accuracy: 0.8312 - dice_coef: 0.7840 - val_loss: 2.3409 - val_accuracy: 0.5431 - val_dice_coef: 0.5334
# Epoch 61/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3899 - accuracy: 0.8295 - dice_coef: 0.7875 - val_loss: 2.3516 - val_accuracy: 0.5418 - val_dice_coef: 0.5324
# Epoch 62/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3905 - accuracy: 0.8286 - dice_coef: 0.7889 - val_loss: 2.3601 - val_accuracy: 0.5375 - val_dice_coef: 0.5279
# Epoch 63/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3888 - accuracy: 0.8270 - dice_coef: 0.7866 - val_loss: 2.3727 - val_accuracy: 0.5366 - val_dice_coef: 0.5276
# Epoch 64/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3883 - accuracy: 0.8289 - dice_coef: 0.7878 - val_loss: 2.3817 - val_accuracy: 0.5369 - val_dice_coef: 0.5288
# Epoch 65/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3819 - accuracy: 0.8505 - dice_coef: 0.7903 - val_loss: 2.3913 - val_accuracy: 0.5359 - val_dice_coef: 0.5279
# Epoch 66/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3820 - accuracy: 0.8502 - dice_coef: 0.7904 - val_loss: 2.4032 - val_accuracy: 0.5370 - val_dice_coef: 0.5287
# Epoch 67/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3788 - accuracy: 0.8519 - dice_coef: 0.7923 - val_loss: 2.4208 - val_accuracy: 0.5372 - val_dice_coef: 0.5279
# Epoch 68/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3846 - accuracy: 0.8478 - dice_coef: 0.7903 - val_loss: 2.4520 - val_accuracy: 0.5353 - val_dice_coef: 0.5248
# Epoch 69/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3801 - accuracy: 0.8499 - dice_coef: 0.7933 - val_loss: 2.4658 - val_accuracy: 0.5305 - val_dice_coef: 0.5217
# Epoch 70/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3772 - accuracy: 0.8529 - dice_coef: 0.7950 - val_loss: 2.4509 - val_accuracy: 0.5323 - val_dice_coef: 0.5241
# Epoch 71/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3747 - accuracy: 0.8526 - dice_coef: 0.7923 - val_loss: 2.4614 - val_accuracy: 0.5389 - val_dice_coef: 0.5307
# Epoch 72/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3815 - accuracy: 0.8521 - dice_coef: 0.7988 - val_loss: 2.4920 - val_accuracy: 0.5359 - val_dice_coef: 0.5231
# Epoch 73/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3728 - accuracy: 0.8535 - dice_coef: 0.8008 - val_loss: 2.5205 - val_accuracy: 0.5309 - val_dice_coef: 0.5151
# Epoch 74/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3653 - accuracy: 0.8549 - dice_coef: 0.8002 - val_loss: 2.4998 - val_accuracy: 0.5359 - val_dice_coef: 0.5271
# Epoch 75/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3719 - accuracy: 0.8523 - dice_coef: 0.7966 - val_loss: 2.4817 - val_accuracy: 0.5439 - val_dice_coef: 0.5369
# Epoch 76/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3682 - accuracy: 0.8569 - dice_coef: 0.8019 - val_loss: 2.4832 - val_accuracy: 0.5464 - val_dice_coef: 0.5395
# Epoch 77/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3653 - accuracy: 0.8561 - dice_coef: 0.8042 - val_loss: 2.4992 - val_accuracy: 0.5442 - val_dice_coef: 0.5366
# Epoch 78/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3644 - accuracy: 0.8533 - dice_coef: 0.8022 - val_loss: 2.5099 - val_accuracy: 0.5447 - val_dice_coef: 0.5322
# Epoch 79/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3657 - accuracy: 0.8533 - dice_coef: 0.7990 - val_loss: 2.5080 - val_accuracy: 0.5488 - val_dice_coef: 0.5381
# Epoch 80/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3612 - accuracy: 0.8565 - dice_coef: 0.8014 - val_loss: 2.4877 - val_accuracy: 0.5560 - val_dice_coef: 0.5490
# Epoch 81/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3629 - accuracy: 0.8552 - dice_coef: 0.8025 - val_loss: 2.4809 - val_accuracy: 0.5596 - val_dice_coef: 0.5526
# Epoch 82/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3606 - accuracy: 0.8558 - dice_coef: 0.8045 - val_loss: 2.4834 - val_accuracy: 0.5588 - val_dice_coef: 0.5515
# Epoch 83/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3569 - accuracy: 0.8550 - dice_coef: 0.8048 - val_loss: 2.4780 - val_accuracy: 0.5604 - val_dice_coef: 0.5508
# Epoch 84/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3567 - accuracy: 0.8560 - dice_coef: 0.8054 - val_loss: 2.4850 - val_accuracy: 0.5643 - val_dice_coef: 0.5517
# Epoch 85/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3581 - accuracy: 0.8567 - dice_coef: 0.8065 - val_loss: 2.4869 - val_accuracy: 0.5684 - val_dice_coef: 0.5580
# Epoch 86/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3566 - accuracy: 0.8577 - dice_coef: 0.8069 - val_loss: 2.4633 - val_accuracy: 0.5719 - val_dice_coef: 0.5641
# Epoch 87/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3570 - accuracy: 0.8547 - dice_coef: 0.8057 - val_loss: 2.4415 - val_accuracy: 0.5738 - val_dice_coef: 0.5653
# Epoch 88/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3539 - accuracy: 0.8550 - dice_coef: 0.8057 - val_loss: 2.4642 - val_accuracy: 0.5690 - val_dice_coef: 0.5603
# Epoch 89/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3539 - accuracy: 0.8546 - dice_coef: 0.8051 - val_loss: 2.5108 - val_accuracy: 0.5697 - val_dice_coef: 0.5576
# Epoch 90/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3523 - accuracy: 0.8566 - dice_coef: 0.8071 - val_loss: 2.4820 - val_accuracy: 0.5750 - val_dice_coef: 0.5671
# Epoch 91/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3527 - accuracy: 0.8572 - dice_coef: 0.8095 - val_loss: 2.4180 - val_accuracy: 0.5803 - val_dice_coef: 0.5738
# Epoch 92/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3506 - accuracy: 0.8569 - dice_coef: 0.8101 - val_loss: 2.4075 - val_accuracy: 0.5811 - val_dice_coef: 0.5718
# Epoch 93/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3502 - accuracy: 0.8569 - dice_coef: 0.8089 - val_loss: 2.4185 - val_accuracy: 0.5770 - val_dice_coef: 0.5703
# Epoch 94/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3508 - accuracy: 0.8560 - dice_coef: 0.8079 - val_loss: 2.3469 - val_accuracy: 0.5843 - val_dice_coef: 0.5783
# Epoch 95/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3481 - accuracy: 0.8567 - dice_coef: 0.8115 - val_loss: 2.3011 - val_accuracy: 0.5914 - val_dice_coef: 0.5853
# Epoch 96/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3448 - accuracy: 0.8588 - dice_coef: 0.8134 - val_loss: 2.3136 - val_accuracy: 0.5922 - val_dice_coef: 0.5869
# Epoch 97/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3436 - accuracy: 0.8580 - dice_coef: 0.8104 - val_loss: 2.2661 - val_accuracy: 0.5983 - val_dice_coef: 0.5917
# Epoch 98/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3405 - accuracy: 0.8594 - dice_coef: 0.8118 - val_loss: 2.1467 - val_accuracy: 0.6120 - val_dice_coef: 0.6043
# Epoch 99/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3462 - accuracy: 0.8573 - dice_coef: 0.8119 - val_loss: 2.1244 - val_accuracy: 0.6184 - val_dice_coef: 0.6100
# Epoch 100/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3437 - accuracy: 0.8574 - dice_coef: 0.8134 - val_loss: 2.1944 - val_accuracy: 0.6155 - val_dice_coef: 0.6071
# Epoch 101/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3438 - accuracy: 0.8584 - dice_coef: 0.8131 - val_loss: 2.2311 - val_accuracy: 0.6126 - val_dice_coef: 0.6039
# Epoch 102/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3454 - accuracy: 0.8581 - dice_coef: 0.8101 - val_loss: 2.1909 - val_accuracy: 0.6157 - val_dice_coef: 0.6060
# Epoch 103/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3420 - accuracy: 0.8575 - dice_coef: 0.8118 - val_loss: 2.1952 - val_accuracy: 0.6100 - val_dice_coef: 0.6026
# Epoch 104/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3415 - accuracy: 0.8574 - dice_coef: 0.8130 - val_loss: 2.2019 - val_accuracy: 0.6110 - val_dice_coef: 0.6045
# Epoch 105/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3423 - accuracy: 0.8573 - dice_coef: 0.8148 - val_loss: 2.2800 - val_accuracy: 0.6072 - val_dice_coef: 0.6000
# Epoch 106/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3360 - accuracy: 0.8596 - dice_coef: 0.8160 - val_loss: 2.2536 - val_accuracy: 0.6119 - val_dice_coef: 0.6050
# Epoch 107/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3361 - accuracy: 0.8600 - dice_coef: 0.8140 - val_loss: 2.2700 - val_accuracy: 0.6095 - val_dice_coef: 0.6024
# Epoch 108/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3404 - accuracy: 0.8595 - dice_coef: 0.8139 - val_loss: 2.3280 - val_accuracy: 0.6013 - val_dice_coef: 0.5944
# Epoch 109/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3362 - accuracy: 0.8602 - dice_coef: 0.8167 - val_loss: 2.3404 - val_accuracy: 0.5984 - val_dice_coef: 0.5918
# Epoch 110/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3401 - accuracy: 0.8557 - dice_coef: 0.8168 - val_loss: 2.3318 - val_accuracy: 0.6020 - val_dice_coef: 0.5948
# Epoch 111/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3336 - accuracy: 0.8587 - dice_coef: 0.8183 - val_loss: 2.3565 - val_accuracy: 0.6042 - val_dice_coef: 0.5948
# Epoch 112/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3355 - accuracy: 0.8581 - dice_coef: 0.8154 - val_loss: 2.3404 - val_accuracy: 0.6074 - val_dice_coef: 0.5981
# Epoch 113/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3347 - accuracy: 0.8596 - dice_coef: 0.8156 - val_loss: 2.2330 - val_accuracy: 0.6172 - val_dice_coef: 0.6098
# Epoch 114/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3318 - accuracy: 0.8600 - dice_coef: 0.8175 - val_loss: 2.1803 - val_accuracy: 0.6213 - val_dice_coef: 0.6144
# Epoch 115/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3338 - accuracy: 0.8590 - dice_coef: 0.8182 - val_loss: 2.1849 - val_accuracy: 0.6210 - val_dice_coef: 0.6137
# Epoch 116/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3288 - accuracy: 0.8605 - dice_coef: 0.8183 - val_loss: 2.2600 - val_accuracy: 0.6148 - val_dice_coef: 0.6078
# Epoch 117/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3343 - accuracy: 0.8591 - dice_coef: 0.8164 - val_loss: 2.3162 - val_accuracy: 0.6108 - val_dice_coef: 0.6040
# Epoch 118/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3320 - accuracy: 0.8605 - dice_coef: 0.8170 - val_loss: 2.3188 - val_accuracy: 0.6094 - val_dice_coef: 0.6039
# Epoch 119/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3304 - accuracy: 0.8602 - dice_coef: 0.8198 - val_loss: 2.3296 - val_accuracy: 0.6049 - val_dice_coef: 0.5999
# Epoch 120/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3245 - accuracy: 0.8612 - dice_coef: 0.8208 - val_loss: 2.3067 - val_accuracy: 0.6058 - val_dice_coef: 0.6001
# Epoch 121/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3263 - accuracy: 0.8624 - dice_coef: 0.8204 - val_loss: 2.2906 - val_accuracy: 0.6066 - val_dice_coef: 0.6006
# Epoch 122/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3255 - accuracy: 0.8649 - dice_coef: 0.8206 - val_loss: 2.2931 - val_accuracy: 0.6072 - val_dice_coef: 0.6022
# Epoch 123/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3273 - accuracy: 0.8632 - dice_coef: 0.8209 - val_loss: 2.3413 - val_accuracy: 0.6030 - val_dice_coef: 0.5983
# Epoch 124/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3270 - accuracy: 0.8626 - dice_coef: 0.8221 - val_loss: 2.2969 - val_accuracy: 0.6078 - val_dice_coef: 0.6028
# Epoch 125/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3245 - accuracy: 0.8616 - dice_coef: 0.8225 - val_loss: 2.1569 - val_accuracy: 0.6254 - val_dice_coef: 0.6193
# Epoch 126/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3275 - accuracy: 0.8602 - dice_coef: 0.8213 - val_loss: 2.1369 - val_accuracy: 0.6276 - val_dice_coef: 0.6214
# Epoch 127/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3269 - accuracy: 0.8633 - dice_coef: 0.8212 - val_loss: 2.1839 - val_accuracy: 0.6222 - val_dice_coef: 0.6182
# Epoch 128/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3283 - accuracy: 0.8658 - dice_coef: 0.8204 - val_loss: 2.0357 - val_accuracy: 0.6404 - val_dice_coef: 0.6353
# Epoch 129/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3229 - accuracy: 0.8671 - dice_coef: 0.8236 - val_loss: 1.8445 - val_accuracy: 0.6631 - val_dice_coef: 0.6558
# Epoch 130/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3221 - accuracy: 0.8643 - dice_coef: 0.8228 - val_loss: 1.7885 - val_accuracy: 0.6682 - val_dice_coef: 0.6601
# Epoch 131/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3222 - accuracy: 0.8657 - dice_coef: 0.8226 - val_loss: 1.7969 - val_accuracy: 0.6666 - val_dice_coef: 0.6596
# Epoch 132/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3214 - accuracy: 0.8638 - dice_coef: 0.8231 - val_loss: 1.7752 - val_accuracy: 0.6722 - val_dice_coef: 0.6660
# Epoch 133/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3168 - accuracy: 0.8667 - dice_coef: 0.8251 - val_loss: 1.7255 - val_accuracy: 0.6808 - val_dice_coef: 0.6758
# Epoch 134/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3174 - accuracy: 0.8684 - dice_coef: 0.8259 - val_loss: 1.7114 - val_accuracy: 0.6815 - val_dice_coef: 0.6761
# Epoch 135/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3157 - accuracy: 0.8708 - dice_coef: 0.8265 - val_loss: 1.6711 - val_accuracy: 0.6827 - val_dice_coef: 0.6755
# Epoch 136/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3150 - accuracy: 0.8704 - dice_coef: 0.8266 - val_loss: 1.5938 - val_accuracy: 0.6888 - val_dice_coef: 0.6801
# Epoch 137/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3192 - accuracy: 0.8662 - dice_coef: 0.8246 - val_loss: 1.4720 - val_accuracy: 0.7036 - val_dice_coef: 0.6953
# Epoch 138/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3175 - accuracy: 0.8672 - dice_coef: 0.8244 - val_loss: 1.4283 - val_accuracy: 0.7125 - val_dice_coef: 0.7058
# Epoch 139/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3156 - accuracy: 0.8691 - dice_coef: 0.8265 - val_loss: 1.3484 - val_accuracy: 0.7236 - val_dice_coef: 0.7169
# Epoch 140/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3190 - accuracy: 0.8699 - dice_coef: 0.8252 - val_loss: 1.2546 - val_accuracy: 0.7359 - val_dice_coef: 0.7284
# Epoch 141/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3169 - accuracy: 0.8691 - dice_coef: 0.8262 - val_loss: 1.2287 - val_accuracy: 0.7379 - val_dice_coef: 0.7282
# Epoch 142/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3140 - accuracy: 0.8689 - dice_coef: 0.8266 - val_loss: 1.2629 - val_accuracy: 0.7327 - val_dice_coef: 0.7236
# Epoch 143/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3114 - accuracy: 0.8700 - dice_coef: 0.8277 - val_loss: 1.3214 - val_accuracy: 0.7266 - val_dice_coef: 0.7198
# Epoch 144/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3142 - accuracy: 0.8709 - dice_coef: 0.8273 - val_loss: 1.3721 - val_accuracy: 0.7213 - val_dice_coef: 0.7136
# Epoch 145/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3165 - accuracy: 0.8707 - dice_coef: 0.8268 - val_loss: 1.4033 - val_accuracy: 0.7117 - val_dice_coef: 0.7040
# Epoch 146/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3095 - accuracy: 0.8743 - dice_coef: 0.8288 - val_loss: 1.3474 - val_accuracy: 0.7155 - val_dice_coef: 0.7079
# Epoch 147/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3134 - accuracy: 0.8720 - dice_coef: 0.8257 - val_loss: 1.2995 - val_accuracy: 0.7249 - val_dice_coef: 0.7165
# Epoch 148/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3108 - accuracy: 0.8737 - dice_coef: 0.8264 - val_loss: 1.3057 - val_accuracy: 0.7291 - val_dice_coef: 0.7196
# Epoch 149/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3076 - accuracy: 0.8744 - dice_coef: 0.8285 - val_loss: 1.3153 - val_accuracy: 0.7287 - val_dice_coef: 0.7202
# Epoch 150/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3068 - accuracy: 0.8744 - dice_coef: 0.8294 - val_loss: 1.2826 - val_accuracy: 0.7333 - val_dice_coef: 0.7247
# Epoch 151/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3097 - accuracy: 0.8719 - dice_coef: 0.8294 - val_loss: 1.3114 - val_accuracy: 0.7308 - val_dice_coef: 0.7226
# Epoch 152/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3080 - accuracy: 0.8724 - dice_coef: 0.8316 - val_loss: 1.3823 - val_accuracy: 0.7229 - val_dice_coef: 0.7159
# Epoch 153/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3052 - accuracy: 0.8757 - dice_coef: 0.8326 - val_loss: 1.4149 - val_accuracy: 0.7185 - val_dice_coef: 0.7125
# Epoch 154/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3073 - accuracy: 0.8767 - dice_coef: 0.8321 - val_loss: 1.3965 - val_accuracy: 0.7188 - val_dice_coef: 0.7119
# Epoch 155/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3059 - accuracy: 0.8765 - dice_coef: 0.8314 - val_loss: 1.3972 - val_accuracy: 0.7145 - val_dice_coef: 0.7074
# Epoch 156/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3057 - accuracy: 0.8750 - dice_coef: 0.8302 - val_loss: 1.3748 - val_accuracy: 0.7151 - val_dice_coef: 0.7082
# Epoch 157/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3075 - accuracy: 0.8729 - dice_coef: 0.8285 - val_loss: 1.3362 - val_accuracy: 0.7225 - val_dice_coef: 0.7160
# Epoch 158/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3028 - accuracy: 0.8752 - dice_coef: 0.8314 - val_loss: 1.3185 - val_accuracy: 0.7280 - val_dice_coef: 0.7220
# Epoch 159/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3034 - accuracy: 0.8782 - dice_coef: 0.8318 - val_loss: 1.3150 - val_accuracy: 0.7285 - val_dice_coef: 0.7242
# Epoch 160/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3036 - accuracy: 0.8775 - dice_coef: 0.8327 - val_loss: 1.3514 - val_accuracy: 0.7248 - val_dice_coef: 0.7197
# Epoch 161/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3051 - accuracy: 0.8756 - dice_coef: 0.8317 - val_loss: 1.3960 - val_accuracy: 0.7174 - val_dice_coef: 0.7125
# Epoch 162/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3044 - accuracy: 0.8754 - dice_coef: 0.8322 - val_loss: 1.4011 - val_accuracy: 0.7148 - val_dice_coef: 0.7107
# Epoch 163/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3002 - accuracy: 0.8779 - dice_coef: 0.8335 - val_loss: 1.3489 - val_accuracy: 0.7224 - val_dice_coef: 0.7186
# Epoch 164/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2995 - accuracy: 0.8781 - dice_coef: 0.8335 - val_loss: 1.3388 - val_accuracy: 0.7269 - val_dice_coef: 0.7225
# Epoch 165/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2995 - accuracy: 0.8770 - dice_coef: 0.8339 - val_loss: 1.3594 - val_accuracy: 0.7262 - val_dice_coef: 0.7219
# Epoch 166/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3012 - accuracy: 0.8762 - dice_coef: 0.8341 - val_loss: 1.3315 - val_accuracy: 0.7306 - val_dice_coef: 0.7266
# Epoch 167/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2985 - accuracy: 0.8758 - dice_coef: 0.8356 - val_loss: 1.2953 - val_accuracy: 0.7368 - val_dice_coef: 0.7315
# Epoch 168/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2988 - accuracy: 0.8772 - dice_coef: 0.8350 - val_loss: 1.2845 - val_accuracy: 0.7400 - val_dice_coef: 0.7332
# Epoch 169/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2949 - accuracy: 0.8778 - dice_coef: 0.8366 - val_loss: 1.2799 - val_accuracy: 0.7411 - val_dice_coef: 0.7345
# Epoch 170/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2988 - accuracy: 0.8767 - dice_coef: 0.8356 - val_loss: 1.2806 - val_accuracy: 0.7403 - val_dice_coef: 0.7351
# Epoch 171/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3020 - accuracy: 0.8764 - dice_coef: 0.8334 - val_loss: 1.2864 - val_accuracy: 0.7414 - val_dice_coef: 0.7350
# Epoch 172/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3024 - accuracy: 0.8751 - dice_coef: 0.8338 - val_loss: 1.2749 - val_accuracy: 0.7435 - val_dice_coef: 0.7369
# Epoch 173/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2989 - accuracy: 0.8781 - dice_coef: 0.8344 - val_loss: 1.2435 - val_accuracy: 0.7505 - val_dice_coef: 0.7436
# Epoch 174/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3030 - accuracy: 0.8761 - dice_coef: 0.8339 - val_loss: 1.2713 - val_accuracy: 0.7461 - val_dice_coef: 0.7403
# Epoch 175/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2956 - accuracy: 0.8795 - dice_coef: 0.8367 - val_loss: 1.3342 - val_accuracy: 0.7382 - val_dice_coef: 0.7324
# Epoch 176/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2966 - accuracy: 0.8793 - dice_coef: 0.8368 - val_loss: 1.3348 - val_accuracy: 0.7376 - val_dice_coef: 0.7326
# Epoch 177/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.3021 - accuracy: 0.8778 - dice_coef: 0.8341 - val_loss: 1.2574 - val_accuracy: 0.7514 - val_dice_coef: 0.7440
# Epoch 178/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2966 - accuracy: 0.8777 - dice_coef: 0.8359 - val_loss: 1.2417 - val_accuracy: 0.7556 - val_dice_coef: 0.7478
# Epoch 179/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2946 - accuracy: 0.8792 - dice_coef: 0.8371 - val_loss: 1.2749 - val_accuracy: 0.7499 - val_dice_coef: 0.7427
# Epoch 180/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2997 - accuracy: 0.8763 - dice_coef: 0.8343 - val_loss: 1.2755 - val_accuracy: 0.7491 - val_dice_coef: 0.7432
# Epoch 181/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2904 - accuracy: 0.8823 - dice_coef: 0.8378 - val_loss: 1.2532 - val_accuracy: 0.7531 - val_dice_coef: 0.7462
# Epoch 182/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2953 - accuracy: 0.8801 - dice_coef: 0.8363 - val_loss: 1.2436 - val_accuracy: 0.7532 - val_dice_coef: 0.7472
# Epoch 183/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2941 - accuracy: 0.8802 - dice_coef: 0.8367 - val_loss: 1.2377 - val_accuracy: 0.7555 - val_dice_coef: 0.7483
# Epoch 184/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2943 - accuracy: 0.8786 - dice_coef: 0.8370 - val_loss: 1.2681 - val_accuracy: 0.7521 - val_dice_coef: 0.7458
# Epoch 185/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2972 - accuracy: 0.8784 - dice_coef: 0.8376 - val_loss: 1.2809 - val_accuracy: 0.7508 - val_dice_coef: 0.7451
# Epoch 186/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2973 - accuracy: 0.8811 - dice_coef: 0.8376 - val_loss: 1.2518 - val_accuracy: 0.7529 - val_dice_coef: 0.7456
# Epoch 187/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2926 - accuracy: 0.8823 - dice_coef: 0.8379 - val_loss: 1.2220 - val_accuracy: 0.7537 - val_dice_coef: 0.7464
# Epoch 188/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2935 - accuracy: 0.8795 - dice_coef: 0.8368 - val_loss: 1.1985 - val_accuracy: 0.7529 - val_dice_coef: 0.7462
# Epoch 189/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2948 - accuracy: 0.8791 - dice_coef: 0.8373 - val_loss: 1.1995 - val_accuracy: 0.7514 - val_dice_coef: 0.7451
# Epoch 190/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2945 - accuracy: 0.8801 - dice_coef: 0.8370 - val_loss: 1.1826 - val_accuracy: 0.7542 - val_dice_coef: 0.7479
# Epoch 191/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2952 - accuracy: 0.8823 - dice_coef: 0.8363 - val_loss: 1.1746 - val_accuracy: 0.7568 - val_dice_coef: 0.7498
# Epoch 192/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2910 - accuracy: 0.8830 - dice_coef: 0.8376 - val_loss: 1.1682 - val_accuracy: 0.7602 - val_dice_coef: 0.7524
# Epoch 193/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2939 - accuracy: 0.8785 - dice_coef: 0.8364 - val_loss: 1.1631 - val_accuracy: 0.7632 - val_dice_coef: 0.7562
# Epoch 194/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2897 - accuracy: 0.8809 - dice_coef: 0.8394 - val_loss: 1.1674 - val_accuracy: 0.7617 - val_dice_coef: 0.7563
# Epoch 195/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2926 - accuracy: 0.8817 - dice_coef: 0.8389 - val_loss: 1.1825 - val_accuracy: 0.7598 - val_dice_coef: 0.7538
# Epoch 196/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2921 - accuracy: 0.8805 - dice_coef: 0.8388 - val_loss: 1.2041 - val_accuracy: 0.7559 - val_dice_coef: 0.7499
# Epoch 197/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2938 - accuracy: 0.8788 - dice_coef: 0.8378 - val_loss: 1.2156 - val_accuracy: 0.7571 - val_dice_coef: 0.7516
# Epoch 198/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2938 - accuracy: 0.8780 - dice_coef: 0.8379 - val_loss: 1.2316 - val_accuracy: 0.7567 - val_dice_coef: 0.7528
# Epoch 199/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2908 - accuracy: 0.8808 - dice_coef: 0.8392 - val_loss: 1.1985 - val_accuracy: 0.7565 - val_dice_coef: 0.7522
# Epoch 200/200
# 1/1 [==============================] - 4s 4s/step - loss: 0.2874 - accuracy: 0.8824 - dice_coef: 0.8404 - val_loss: 1.2315 - val_accuracy: 0.7486 - val_dice_coef: 0.7452

# %%
PlotHistory(transfer_model_history, 'loss')

# %%
PlotHistory(transfer_model_history, 'accuracy')

# %%
plt.figure(figsize=(12,10))
plt.xlabel('Epoch Number')
plt.ylabel('Dice_Coef')
plt.plot(transfer_model_history.history['dice_coef'])
plt.plot(transfer_model_history.history['val_dice_coef'])
plt.title('Dice_Coef')
plt.legend(["Dice_Train", "Dice_Val"])   
plt.show()

# %%
pred_train_f3 = transfer_model_unet.predict(x_train_f3)
print(pred_train_f3.shape)
pred_mask_f3 = tf.argmax(pred_train_f3, axis=-1)
  # # pred_mask becomes [IMG_SIZE, IMG_SIZE]
  # # but matplotlib needs [IMG_SIZE, IMG_SIZE, 1]
pred_mask_f3 = tf.expand_dims(pred_mask_f3, axis=-1)
print(pred_mask_f3.shape)
# Out:
# (6, 128, 128, 7)
# (6, 128, 128, 1)

# %%
fig, ax = plt.subplots(1,2, figsize=(10,8))

ax[0].imshow(pred_mask_f3[0, :, :, 0])
ax[0].set_xlabel('X (km)')
ax[0].set_ylabel('Time (s)')
ax[0].set_title('Predicted Facies')
ax[1].imshow(y_train_f3[0, :, :])
ax[1].set_xlabel('X (km)')
ax[1].set_ylabel('Time (s)')
ax[1].set_title('True Facies (Labels)')
fig.suptitle('Transfer Learning Prediction with Training (Netherlands F3)', fontsize=14, y=0.82)
plt.show()

# %%
pred_test_f3 = transfer_model_unet.predict(x_test_f3)
print(pred_test_f3.shape)
pred_mask_f3_test = tf.argmax(pred_test_f3, axis=-1)
  # # pred_mask becomes [IMG_SIZE, IMG_SIZE]
  # # but matplotlib needs [IMG_SIZE, IMG_SIZE, 1]
pred_mask_f3_test = tf.expand_dims(pred_mask_f3_test, axis=-1)
print(pred_mask_f3_test.shape)
# Out:
# (199, 128, 128, 7)
# (199, 128, 128, 1)

# %%
transfer_model_unet.evaluate(x=x_test_f3, y=y_test_f3, callbacks=[tensorboard_callback])
# Out:
# 7/7 [==============================] - 1s 80ms/step - loss: 0.8883 - accuracy: 0.8108 - dice_coef: 0.8081
# [0.8882575631141663, 0.8107677102088928, 0.8080587983131409]

# %%
fig, ax = plt.subplots(1,2, figsize=(12,12))

ax[0].imshow(pred_mask_f3_test[1, :, :, 0])
ax[0].set_xlabel('X (km)', fontsize=13)
ax[0].set_ylabel('Time (s)', fontsize=13)
ax[0].set_title('Predicted Facies', fontsize=13)
ax[1].imshow(y_test_f3[1, :, :])
ax[1].set_xlabel('X (km)', fontsize=13)
ax[1].set_ylabel('Time (s)', fontsize=13)
ax[1].set_title('True Facies (Labels)', fontsize=13)
fig.suptitle('Transfer Learning Prediction with Test (Netherlands F3)', fontsize=14, y=0.75)
plt.show()
