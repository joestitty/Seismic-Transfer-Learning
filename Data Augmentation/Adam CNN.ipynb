# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

import math
from scipy.signal.windows import triang
from scipy.signal import convolve2d as conv2

from tqdm.notebook import tqdm #progress bar

import cv2

from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
parihaka = np.load('/content/drive/MyDrive/CS230 Project/Dataset /data_train.npz', mmap_mode = 'r')['data']

# %%
p_max, p_min, p_mean, p_median = (np.max(parihaka), np.min(parihaka), np.mean(parihaka), np.median(parihaka))

# %%
flattened_data = parihaka.flatten()

# %%
mean, stdev = norm.fit(flattened_data)

# %%
print(p_mean, p_min, p_max)
p_integral = p_mean * (p_max - p_min)
print(p_integral)
temp = norm.pdf(x_axis, mean, stdev) * p_integral
print(temp)
plt.plot(x_axis, temp)
# Out:
# 0.67661 -5195.5234 5151.7188
# 7001.0474
# [2.33326227e-38 2.41421273e-38 2.49795529e-38 ... 1.16658808e-37
#  1.12781492e-37 1.09032328e-37]

# %%
x_axis = np.arange(p_min, p_max, 1)
plt.figure()
_ = plt.hist(flattened_data, bins=1000)
scaled_norm = norm.pdf(x_axis, mean, stdev/1.1) * p_integral * 1e6
_ = plt.plot(x_axis, scaled_norm)
plt.show()

# %%
print(mean, stdev)
# Out:
# 0.6766046 390.3082
